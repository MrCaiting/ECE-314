# %% [markdown]
# # Lab 11: ODEs, Failure Rates, and Evolutionary Games

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as img
import numpy as np
import scipy as sp
import scipy.stats as st
from scipy.integrate import odeint
print 'Modules Imported!'
# Out:
# Modules Imported!

# %% [markdown]
# In this lab we're to going analyze evolutionary games using drift analysis. In order to do this, we first need to determine how to integrate ordinary differential equations. So, we begin with a brief exposure of how to achieve this in Python. While we're at it, we'll do a short exercise about failure rate functions.  Then we examine some evolutionary games, using both a stochastic model and a deterministic model, which involves the differential equations.

# %% [markdown]
# ## Integration of ODEs

# %% [markdown]
# This section gives an introdution to integrating ordinary differential equations (odes), with an application to the calculation of a CDF from a failure rate function.  If you recall from your math classes we can describe an ODE as the following:
#
# $\dot{y}=f(y),$
#
# where both $y$ and the function $f$ are vector valued, and $\dot{y}$ is shorthand for $\frac{dy}{dt}.$   The variables being vector valued simply implies that we could have a system of dependent one dimensional (1D) ODEs as opposed to just a single one dimensional variable.  Let's look at the following system:
#
# \begin{eqnarray*}
# \binom{\dot{y_0}}{\dot{y_1}} = \binom{2y_1-0.1y_0}{-y_0}
# \end{eqnarray*}
# with the initial condition $y_{init}=\binom{y_1(0)}{y_2(0)}=\binom{1}{1}.$
#
# Our goal in using Python is not to find a closed form solution to the ODE as you would have probably done in your math class, but to numerically integrate it and produce a graphical solution. In order to do this we use the odeint method from scipy.integrate. It takes a function with an initial value and specified times at which the solution is to be output. Internally, the numerical method will often use a much finer grid of time points to solve the ode -- but that is none of your concern.   The times you put in are the times at with the method needs to provide the values of the solution. Look how it is used below:

# %%
# Simple example integrating a 2d ordinary differential equation (ode) dy/dt=f(y,t) 
# Note that the odeint package is imported in the code at the beginning of this file.

# Function to integrate over
def f(y,t):    
    return np.array([2.*y[1]-.1*y[0],-y[0] ])

time=np.linspace(0.0,20.0,10000)   # The times at which the solution is output.
yinit=np.array([1.0,1.0])   # The initial condition
y=odeint(f,yinit,time)      

plt.plot(y[:,0],y[:,1])
plt.title('trajectory of y up to time 20')
plt.ylabel('y_1')
plt.xlabel('y_0')

# %% [markdown]
# Typically in a plot like this you would add an arrow to indicate the direction of time in the graph. However, we know the initial state is $y_{init}=\binom{1}{1}.$ So as time increases, the trajectory moves concentrically inwards in a clockwise fashion. Depending on how much of differential equations you remember, this solution should make sense. The equation happens to have a linear form and can be written as $\dot y = Ay$ where
# $
# A=\left( \begin{array}{cc}  -0.1  &  2  \\  -1  & 0 \end{array} \right).
# $
# The eigenvalues of $A$ are complex with negative real parts, so we would expect a decaying oscillatory behavior. (If you didn't follow that, don't worry about it.)
#
# As a simple application of integrating a 1D (one-dimensional) ode, the following code calculates a CDF $F$ from its failure rate function $h.$ But first, let's look at some theory to remember what a failure rate function is. If we let $T$ be a positive random variable with a pdf $f_T$ then
# the failure rate function is defined by the following:
#
# $$h(t)=\lim_{\epsilon \to 0} \frac{P(t<T \leq t+\epsilon | T>t)}{\epsilon}$$
#
# Equivalently, an object having failure rate function $h$ means that for any $t > 0,$ given
# that the object is still working at time $t$, the probability it will fail in the next
# $\epsilon$ time units is $h(t)\epsilon + o(\epsilon)$.  (As usual, $o(\epsilon)$ represents an error term such that $o(\epsilon)/\epsilon \to 0$ as $\epsilon\to 0.$)  With a little bit more derivation (shown in Section 3.9 of your ECE 313 text), we can see that:
#
# $$h(t) = \frac{f_T(t)}{1-F_T(t)}$$
#
# Of course, the pdf $f_T$ is the derivative of the CDF $F_T$. Here's where your 1D ODE comes into play. Given a failure rate function, we want to be able to calculate the CDF. We can easily turn this into an ODE.
#
# $f_T(t) = (1-F_T(t))h(t)$
#
# Let $F_T(t) = y$ and  $f_T(t) = \frac{dy}{dt} = \dot{y}$, then:
#
# $\dot{y} = (1-y)h(t)$
#
# Now we have our differential equation set up and we can solve it by the same method used in the previous example. For the code below, we define a particular bathtub shaped failure rate function to model the lifetime of a component such as a hard disk drive. There is a high, but decreasing initial rate of failure, followed be a period with a very low rate failure, followed by an increasing rate of failure. You should be able to think of reasons why an object might exhibit this type of failure rate function. Notice that the CDF behaves as we would expect: always between 0 and 1, and reactive to $h(t)$.
#
# If you examine the ECE 313 notes you'll see another way to determine $F_T,$  namely, using
# $F_T(t) = 1- \exp \left( \int_o^t -h(s) ds \right)$.  The point here, though, is to get some practice using
# odeint, instead of using this formula.

# %%
# Calculation of CDF from its failure rate function, using dF/dt=(1-F(t))h(t)
from scipy.integrate import odeint

def h(t):   # h is the failure rate function with a bathtub shape
    if t<1:
        return 1-t
    elif t<3:
        return 0.0
    else:
        return np.sqrt(t-3)

def Fdot(y,t):    
    return (1-y)*h(t)

t_max=8.0  #  Select so that F(t_max) is very close to one
time=np.linspace(0.0,t_max,1000)
Finit=0.0
F=odeint(Fdot,Finit,time)

plt.plot(time,map(h,time))
plt.text(4,h(4)+0.5, r'$h(t)$',fontsize=24) #Plots labels in the graph
plt.text(4,0.5, r'$F(t)$',fontsize=24) 

plt.plot(time,F)
plt.title('failure rate function $h$ and associated CDF, $F$')
plt.axis(ymin=0,ymax=2.0)
plt.ylabel('$h(t), F(t)$',fontsize=20)
plt.xlabel('$t$',fontsize=20)

# %% [markdown]
# **<SPAN style="BACKGROUND-COLOR: #C0C0C0">Problem 1:</SPAN>** Using the information on failure rate functions and the example above, do the following:
# <ol>
# <li> Write code that, given the failure rate function of a random variable $T$, computes the mean lifetime, $E[T].$  Use this code to determine the mean lifetime for the example given above.  (Hint: An easy way to do this problem is to use the area rule for expectations. Since $T$ is nonnegative, the area rule for expectations gives $E[T]=\int_0^\infty(1-F(t)) dt.$
# The integral $\int_0^\infty (1-F(t)) dt$ is approximately equal to
# $\int_0^{t_{max}} (1-F(t)) dt,$  which, by the definition of Riemann integration, is approximately equal to
# $h \sum_{i=1}^{1000} (1-F(h_i)) $ where $h=t_{max}/1000.$  Basically the code above returns the samples $F(h_i)$ so all you need to do is subtract these values from 1, sum them up and multiply by $h$.)
# <li> What happens to $E[T]$ if the failure rate function is doubled for all time? Print out the new value of $E[T]$.
# </ol>

# %%
######## Part 1 ########
F_hi = [1-x for x in F]
F_thou = np.asarray(F_hi[:1000])
h = 1.*t_max/1000
mean = h*F_thou.sum()
print "The mean lifetime is", mean
# Out:
# The mean lifetime is 2.65652422005

# %%
######## Part 2 ########
def h_double(t):   # h is the failure rate function with a bathtub shape
    if t<1:
        return 2*(1-t)
    elif t<3:
        return 0.0
    else:
        return 2*np.sqrt(t-3)

def Fdot_double(y,t):    
    return (1-y)*h_double(t)

t_max = 8.0  #  Select so that F(t_max) is very close to one
time = np.linspace(0.0,t_max,1000)
Finit = 0.0
F = odeint(Fdot_double,Finit,time)

F_hi = [1-x for x in F]
F_thou = np.asarray(F_hi[:1000])
h = 1.*t_max/1000
mean = h*F_thou.sum()
print "When the failure rate function is doubled for all time, the mean lifetime is", mean
# Out:
# When the failure rate function is doubled for all time, the mean lifetime is 1.55044485925

# %% [markdown]
# __Answer:__ $\textbf{2.}$ When the failure rate function is doubled, the mean lifetime goes down.

# %% [markdown]
# **<SPAN style="BACKGROUND-COLOR: #C0C0C0">End of Problem 1</SPAN>**

# %% [markdown]
# ## Evolutionary games (replicator dynamics):

# %% [markdown]
# Consider a population of individuals, where each individual is of some type.  Suppose individuals have occasional pairwise encounters.  During an encounter the two individuals involved play a two player symmetric game in which the strategies are the types of the individuals.   As a result of the encounter, each of the two individuals produces a number of offspring of its same type, with the number being determined by a fitess table or, equivalently, a fitness matrix.   For example, consider a population of crickets such that each cricket is either small or large.   If two small crickets meet each other then they each spawn five more small crickets.  If a small cricket encounters a large cricket then the small cricket spawns one more small cricket and the large cricket spawns eight new large crickets.   If two large crickets meet then each of them spawns three new large crickets.  We can summarize these outcomes using the following table:
# $$\begin{array}{c|cc}  & small & large  \\ \hline
#     small & 5 & 1  \\
#     large & 8 & 3
#     \end{array}$$
# or by a fitness matrix
# $$F=\left( \begin{array}{cc}  5 & 1 \\ 8 & 3  \end{array}\right).$$
# Associating 0 with "small" and 1 with "large,"  we see that if a type i individual encounters a type j individual, then the type i individual spawns F[i,j] new individuals of type i, and the type j individual spawns F[j,i] new individuals of type j. Below is a stochastic simulation for this game where we start with a population of four small crickets and four large crickets. It may be a useful exercise for you to think of how the values for $a$ and $b$ were created.

# %%
# Stochastic simulation of replicator dynamics for cricket game

F=np.array([[5,1],[8,3]])  # fitness matrix

n=np.array([4, 4])  #[number of small crickets, number of large crickets], initialized
print "                                   State      Fractions of each type"
print "Initially                        ", n, "      ", n/1./np.sum(n)

T = 1000 #total number of encounters

for k in range(T):   # k tracks number of encounters
    a=n[0]*(n[0]-1.0)/((n[0]+n[1])*(n[0]+n[1]-1))  # probability both players are type 0
    b=2*n[0]*n[1]/((n[0]+n[1])*(n[0]+n[1]-1.0))  # probability one player of each type
    U=np.random.rand()
    if U<=a:
        n+=[2*F[0,0],0]
        print "Round",k+1,"two small crickets meet ", n, n/1./np.sum(n)
    elif a<U<=a+b:
        n+=[F[0,1],F[1,0]]
        print "Round",k+1,"a small meets a large   ", n, n/1./np.sum(n)
    else:
        n+=[0,2*F[1,1]]
        print "Round",k+1,"two large crickets meet ", n, n/1./np.sum(n)
# Out:
#                                    State      Fractions of each type
# Initially                         [4 4]        [ 0.5  0.5]
# Round 1 a small meets a large    [ 5 12] [ 0.29411765  0.70588235]
# Round 2 two large crickets meet  [ 5 18] [ 0.2173913  0.7826087]
# Round 3 a small meets a large    [ 6 26] [ 0.1875  0.8125]
# Round 4 a small meets a large    [ 7 34] [ 0.17073171  0.82926829]
# Round 5 two large crickets meet  [ 7 40] [ 0.14893617  0.85106383]
# Round 6 a small meets a large    [ 8 48] [ 0.14285714  0.85714286]
# Round 7 two large crickets meet  [ 8 54] [ 0.12903226  0.87096774]
# Round 8 two large crickets meet  [ 8 60] [ 0.11764706  0.88235294]
# Round 9 a small meets a large    [ 9 68] [ 0.11688312  0.88311688]
# Round 10 two small crickets meet  [19 68] [ 0.2183908  0.7816092]
# Round 11 two small crickets meet  [29 68] [ 0.29896907  0.70103093]
# Round 12 a small meets a large    [30 76] [ 0.28301887  0.71698113]
# Round 13 two large crickets meet  [30 82] [ 0.26785714  0.73214286]
# Round 14 a small meets a large    [31 90] [ 0.25619835  0.74380165]
# Round 15 two large crickets meet  [31 96] [ 0.24409449  0.75590551]
# Round 16 two large crickets meet  [ 31 102] [ 0.23308271  0.76691729]
# Round 17 two large crickets meet  [ 31 108] [ 0.22302158  0.77697842]
# Round 18 two large crickets meet  [ 31 114] [ 0.2137931  0.7862069]
# Round 19 two large crickets meet  [ 31 120] [ 0.20529801  0.79470199]
# Round 20 a small meets a large    [ 32 128] [ 0.2  0.8]
# Round 21 a small meets a large    [ 33 136] [ 0.19526627  0.80473373]
# Round 22 two large crickets meet  [ 33 142] [ 0.18857143  0.81142857]
# Round 23 two large crickets meet  [ 33 148] [ 0.18232044  0.81767956]
# Round 24 a small meets a large    [ 34 156] [ 0.17894737  0.82105263]
# Round 25 two large crickets meet  [ 34 162] [ 0.17346939  0.82653061]
# Round 26 two large crickets meet  [ 34 168] [ 0.16831683  0.83168317]
# Round 27 two large crickets meet  [ 34 174] [ 0.16346154  0.83653846]
# Round 28 two large crickets meet  [ 34 180] [ 0.1588785  0.8411215]
# Round 29 a small meets a large    [ 35 188] [ 0.15695067  0.84304933]
# Round 30 two large crickets meet  [ 35 194] [ 0.15283843  0.84716157]
# Round 31 two large crickets meet  [ 35 200] [ 0.14893617  0.85106383]
# Round 32 a small meets a large    [ 36 208] [ 0.14754098  0.85245902]
# Round 33 two large crickets meet  [ 36 214] [ 0.144  0.856]
# Round 34 two large crickets meet  [ 36 220] [ 0.140625  0.859375]
# Round 35 two large crickets meet  [ 36 226] [ 0.13740458  0.86259542]
# Round 36 two large crickets meet  [ 36 232] [ 0.13432836  0.86567164]
# Round 37 a small meets a large    [ 37 240] [ 0.13357401  0.86642599]
# Round 38 two large crickets meet  [ 37 246] [ 0.13074205  0.86925795]
# Round 39 two large crickets meet  [ 37 252] [ 0.12802768  0.87197232]
# Round 40 two large crickets meet  [ 37 258] [ 0.12542373  0.87457627]
# Round 41 two large crickets meet  [ 37 264] [ 0.12292359  0.87707641]
# Round 42 two large crickets meet  [ 37 270] [ 0.12052117  0.87947883]
# Round 43 a small meets a large    [ 38 278] [ 0.12025316  0.87974684]
# Round 44 two large crickets meet  [ 38 284] [ 0.11801242  0.88198758]
# Round 45 a small meets a large    [ 39 292] [ 0.11782477  0.88217523]
# Round 46 a small meets a large    [ 40 300] [ 0.11764706  0.88235294]
# Round 47 two large crickets meet  [ 40 306] [ 0.11560694  0.88439306]
# Round 48 two large crickets meet  [ 40 312] [ 0.11363636  0.88636364]
# Round 49 two large crickets meet  [ 40 318] [ 0.11173184  0.88826816]
# Round 50 a small meets a large    [ 41 326] [ 0.11171662  0.88828338]
# Round 51 two large crickets meet  [ 41 332] [ 0.10991957  0.89008043]
# Round 52 a small meets a large    [ 42 340] [ 0.10994764  0.89005236]
# Round 53 two large crickets meet  [ 42 346] [ 0.10824742  0.89175258]
# Round 54 a small meets a large    [ 43 354] [ 0.10831234  0.89168766]
# Round 55 two large crickets meet  [ 43 360] [ 0.10669975  0.89330025]
# Round 56 a small meets a large    [ 44 368] [ 0.10679612  0.89320388]
# Round 57 two large crickets meet  [ 44 374] [ 0.10526316  0.89473684]
# Round 58 two large crickets meet  [ 44 380] [ 0.10377358  0.89622642]
# Round 59 a small meets a large    [ 45 388] [ 0.1039261  0.8960739]
# Round 60 two large crickets meet  [ 45 394] [ 0.10250569  0.89749431]
# Round 61 two large crickets meet  [ 45 400] [ 0.1011236  0.8988764]
# Round 62 two large crickets meet  [ 45 406] [ 0.09977827  0.90022173]
# Round 63 a small meets a large    [ 46 414] [ 0.1  0.9]
# Round 64 two large crickets meet  [ 46 420] [ 0.09871245  0.90128755]
# Round 65 two large crickets meet  [ 46 426] [ 0.09745763  0.90254237]
# Round 66 two large crickets meet  [ 46 432] [ 0.09623431  0.90376569]
# Round 67 two large crickets meet  [ 46 438] [ 0.09504132  0.90495868]
# Round 68 two large crickets meet  [ 46 444] [ 0.09387755  0.90612245]
# Round 69 two large crickets meet  [ 46 450] [ 0.09274194  0.90725806]
# Round 70 two large crickets meet  [ 46 456] [ 0.09163347  0.90836653]
# Round 71 two large crickets meet  [ 46 462] [ 0.09055118  0.90944882]
# Round 72 a small meets a large    [ 47 470] [ 0.09090909  0.90909091]
# Round 73 two large crickets meet  [ 47 476] [ 0.08986616  0.91013384]
# Round 74 two large crickets meet  [ 47 482] [ 0.08884688  0.91115312]
# Round 75 two large crickets meet  [ 47 488] [ 0.08785047  0.91214953]
# Round 76 two large crickets meet  [ 47 494] [ 0.08687616  0.91312384]
# Round 77 two large crickets meet  [ 47 500] [ 0.08592322  0.91407678]
# Round 78 two large crickets meet  [ 47 506] [ 0.08499096  0.91500904]
# Round 79 two large crickets meet  [ 47 512] [ 0.08407871  0.91592129]
# Round 80 two large crickets meet  [ 47 518] [ 0.08318584  0.91681416]
# Round 81 two large crickets meet  [ 47 524] [ 0.08231173  0.91768827]
# Round 82 two large crickets meet  [ 47 530] [ 0.08145581  0.91854419]
# Round 83 two large crickets meet  [ 47 536] [ 0.0806175  0.9193825]
# Round 84 two large crickets meet  [ 47 542] [ 0.07979626  0.92020374]
# Round 85 two large crickets meet  [ 47 548] [ 0.0789916  0.9210084]
# Round 86 two large crickets meet  [ 47 554] [ 0.078203  0.921797]
# Round 87 two large crickets meet  [ 47 560] [ 0.07742998  0.92257002]
# Round 88 two large crickets meet  [ 47 566] [ 0.0766721  0.9233279]
# Round 89 two large crickets meet  [ 47 572] [ 0.07592892  0.92407108]
# Round 90 two large crickets meet  [ 47 578] [ 0.0752  0.9248]
# Round 91 two large crickets meet  [ 47 584] [ 0.07448494  0.92551506]
# Round 92 two large crickets meet  [ 47 590] [ 0.07378336  0.92621664]
# Round 93 two large crickets meet  [ 47 596] [ 0.07309487  0.92690513]
# Round 94 two large crickets meet  [ 47 602] [ 0.07241911  0.92758089]
# Round 95 two large crickets meet  [ 47 608] [ 0.07175573  0.92824427]
# Round 96 two large crickets meet  [ 47 614] [ 0.07110439  0.92889561]
# Round 97 two large crickets meet  [ 47 620] [ 0.07046477  0.92953523]
# Round 98 two large crickets meet  [ 47 626] [ 0.06983655  0.93016345]
# Round 99 a small meets a large    [ 48 634] [ 0.07038123  0.92961877]
# Round 100 two large crickets meet  [ 48 640] [ 0.06976744  0.93023256]
# Round 101 two large crickets meet  [ 48 646] [ 0.06916427  0.93083573]
# Round 102 two large crickets meet  [ 48 652] [ 0.06857143  0.93142857]
# Round 103 two large crickets meet  [ 48 658] [ 0.06798867  0.93201133]
# Round 104 two large crickets meet  [ 48 664] [ 0.06741573  0.93258427]
# Round 105 a small meets a large    [ 49 672] [ 0.06796117  0.93203883]
# Round 106 two large crickets meet  [ 49 678] [ 0.06740028  0.93259972]
# Round 107 a small meets a large    [ 50 686] [ 0.06793478  0.93206522]
# Round 108 two large crickets meet  [ 50 692] [ 0.06738544  0.93261456]
# Round 109 two large crickets meet  [ 50 698] [ 0.06684492  0.93315508]
# Round 110 two large crickets meet  [ 50 704] [ 0.066313  0.933687]
# Round 111 two large crickets meet  [ 50 710] [ 0.06578947  0.93421053]
# Round 112 two large crickets meet  [ 50 716] [ 0.06527415  0.93472585]
# Round 113 two large crickets meet  [ 50 722] [ 0.06476684  0.93523316]
# Round 114 two large crickets meet  [ 50 728] [ 0.06426735  0.93573265]
# Round 115 two large crickets meet  [ 50 734] [ 0.06377551  0.93622449]
# Round 116 two large crickets meet  [ 50 740] [ 0.06329114  0.93670886]
# Round 117 two large crickets meet  [ 50 746] [ 0.06281407  0.93718593]
# Round 118 two large crickets meet  [ 50 752] [ 0.06234414  0.93765586]
# Round 119 two large crickets meet  [ 50 758] [ 0.06188119  0.93811881]
# Round 120 two large crickets meet  [ 50 764] [ 0.06142506  0.93857494]
# Round 121 two large crickets meet  [ 50 770] [ 0.06097561  0.93902439]
# Round 122 two large crickets meet  [ 50 776] [ 0.06053269  0.93946731]
# Round 123 two large crickets meet  [ 50 782] [ 0.06009615  0.93990385]
# Round 124 two large crickets meet  [ 50 788] [ 0.05966587  0.94033413]
# Round 125 two large crickets meet  [ 50 794] [ 0.05924171  0.94075829]
# Round 126 two large crickets meet  [ 50 800] [ 0.05882353  0.94117647]
# Round 127 two large crickets meet  [ 50 806] [ 0.05841121  0.94158879]
# Round 128 two large crickets meet  [ 50 812] [ 0.05800464  0.94199536]
# Round 129 two large crickets meet  [ 50 818] [ 0.05760369  0.94239631]
# Round 130 two large crickets meet  [ 50 824] [ 0.05720824  0.94279176]
# Round 131 a small meets a large    [ 51 832] [ 0.05775764  0.94224236]
# Round 132 two large crickets meet  [ 51 838] [ 0.05736783  0.94263217]
# Round 133 two large crickets meet  [ 51 844] [ 0.05698324  0.94301676]
# Round 134 a small meets a large    [ 52 852] [ 0.05752212  0.94247788]
# Round 135 two large crickets meet  [ 52 858] [ 0.05714286  0.94285714]
# Round 136 a small meets a large    [ 53 866] [ 0.05767138  0.94232862]
# Round 137 two large crickets meet  [ 53 872] [ 0.0572973  0.9427027]
# Round 138 two large crickets meet  [ 53 878] [ 0.05692803  0.94307197]
# Round 139 two large crickets meet  [ 53 884] [ 0.0565635  0.9434365]
# Round 140 two large crickets meet  [ 53 890] [ 0.05620361  0.94379639]
# Round 141 two large crickets meet  [ 53 896] [ 0.05584826  0.94415174]
# Round 142 two large crickets meet  [ 53 902] [ 0.05549738  0.94450262]
# Round 143 two large crickets meet  [ 53 908] [ 0.05515088  0.94484912]
# Round 144 two large crickets meet  [ 53 914] [ 0.05480869  0.94519131]
# Round 145 two large crickets meet  [ 53 920] [ 0.05447071  0.94552929]
# Round 146 a small meets a large    [ 54 928] [ 0.05498982  0.94501018]
# Round 147 two large crickets meet  [ 54 934] [ 0.05465587  0.94534413]
# Round 148 two large crickets meet  [ 54 940] [ 0.05432596  0.94567404]
# Round 149 two large crickets meet  [ 54 946] [ 0.054  0.946]
# Round 150 two large crickets meet  [ 54 952] [ 0.05367793  0.94632207]
# Round 151 two large crickets meet  [ 54 958] [ 0.05335968  0.94664032]
# Round 152 two large crickets meet  [ 54 964] [ 0.05304519  0.94695481]
# Round 153 two large crickets meet  [ 54 970] [ 0.05273438  0.94726562]
# Round 154 two large crickets meet  [ 54 976] [ 0.05242718  0.94757282]
# Round 155 two large crickets meet  [ 54 982] [ 0.05212355  0.94787645]
# Round 156 two large crickets meet  [ 54 988] [ 0.05182342  0.94817658]
# Round 157 two large crickets meet  [ 54 994] [ 0.05152672  0.94847328]
# Round 158 two large crickets meet  [  54 1000] [ 0.0512334  0.9487666]
# Round 159 two large crickets meet  [  54 1006] [ 0.0509434  0.9490566]
# Round 160 two large crickets meet  [  54 1012] [ 0.05065666  0.94934334]
# Round 161 two large crickets meet  [  54 1018] [ 0.05037313  0.94962687]
# Round 162 two large crickets meet  [  54 1024] [ 0.05009276  0.94990724]
# Round 163 two large crickets meet  [  54 1030] [ 0.0498155  0.9501845]
# Round 164 two large crickets meet  [  54 1036] [ 0.04954128  0.95045872]
# Round 165 two large crickets meet  [  54 1042] [ 0.04927007  0.95072993]
# Round 166 two large crickets meet  [  54 1048] [ 0.04900181  0.95099819]
# Round 167 two large crickets meet  [  54 1054] [ 0.04873646  0.95126354]
# Round 168 two large crickets meet  [  54 1060] [ 0.04847397  0.95152603]
# Round 169 a small meets a large    [  55 1068] [ 0.04897596  0.95102404]
# Round 170 two large crickets meet  [  55 1074] [ 0.04871568  0.95128432]
# Round 171 two large crickets meet  [  55 1080] [ 0.04845815  0.95154185]
# Round 172 two large crickets meet  [  55 1086] [ 0.04820333  0.95179667]
# Round 173 two large crickets meet  [  55 1092] [ 0.04795118  0.95204882]
# Round 174 two large crickets meet  [  55 1098] [ 0.04770165  0.95229835]
# Round 175 a small meets a large    [  56 1106] [ 0.04819277  0.95180723]
# Round 176 two large crickets meet  [  56 1112] [ 0.04794521  0.95205479]
# Round 177 two large crickets meet  [  56 1118] [ 0.04770017  0.95229983]
# Round 178 two large crickets meet  [  56 1124] [ 0.04745763  0.95254237]
# Round 179 two large crickets meet  [  56 1130] [ 0.04721754  0.95278246]
# Round 180 two large crickets meet  [  56 1136] [ 0.04697987  0.95302013]
# Round 181 a small meets a large    [  57 1144] [ 0.04746045  0.95253955]
# Round 182 two large crickets meet  [  57 1150] [ 0.04722452  0.95277548]
# Round 183 two large crickets meet  [  57 1156] [ 0.04699093  0.95300907]
# Round 184 two large crickets meet  [  57 1162] [ 0.04675964  0.95324036]
# Round 185 two large crickets meet  [  57 1168] [ 0.04653061  0.95346939]
# Round 186 two large crickets meet  [  57 1174] [ 0.04630382  0.95369618]
# Round 187 a small meets a large    [  58 1182] [ 0.04677419  0.95322581]
# Round 188 two large crickets meet  [  58 1188] [ 0.04654896  0.95345104]
# Round 189 two large crickets meet  [  58 1194] [ 0.04632588  0.95367412]
# Round 190 two large crickets meet  [  58 1200] [ 0.04610493  0.95389507]
# Round 191 a small meets a large    [  59 1208] [ 0.04656669  0.95343331]
# Round 192 two large crickets meet  [  59 1214] [ 0.04634721  0.95365279]
# Round 193 two large crickets meet  [  59 1220] [ 0.04612979  0.95387021]
# Round 194 two large crickets meet  [  59 1226] [ 0.0459144  0.9540856]
# Round 195 two large crickets meet  [  59 1232] [ 0.04570101  0.95429899]
# Round 196 two large crickets meet  [  59 1238] [ 0.04548959  0.95451041]
# Round 197 two large crickets meet  [  59 1244] [ 0.04528012  0.95471988]
# Round 198 two large crickets meet  [  59 1250] [ 0.04507257  0.95492743]
# Round 199 two large crickets meet  [  59 1256] [ 0.04486692  0.95513308]
# Round 200 two large crickets meet  [  59 1262] [ 0.04466313  0.95533687]
# Round 201 two large crickets meet  [  59 1268] [ 0.04446119  0.95553881]
# Round 202 two large crickets meet  [  59 1274] [ 0.04426107  0.95573893]
# Round 203 two large crickets meet  [  59 1280] [ 0.04406273  0.95593727]
# Round 204 two large crickets meet  [  59 1286] [ 0.04386617  0.95613383]
# Round 205 two large crickets meet  [  59 1292] [ 0.04367135  0.95632865]
# Round 206 a small meets a large    [  60 1300] [ 0.04411765  0.95588235]
# Round 207 two large crickets meet  [  60 1306] [ 0.04392387  0.95607613]
# Round 208 two large crickets meet  [  60 1312] [ 0.04373178  0.95626822]
# Round 209 two large crickets meet  [  60 1318] [ 0.04354136  0.95645864]
# Round 210 two large crickets meet  [  60 1324] [ 0.0433526  0.9566474]
# Round 211 two large crickets meet  [  60 1330] [ 0.04316547  0.95683453]
# Round 212 two large crickets meet  [  60 1336] [ 0.04297994  0.95702006]
# Round 213 two large crickets meet  [  60 1342] [ 0.04279601  0.95720399]
# Round 214 two large crickets meet  [  60 1348] [ 0.04261364  0.95738636]
# Round 215 two large crickets meet  [  60 1354] [ 0.04243281  0.95756719]
# Round 216 two large crickets meet  [  60 1360] [ 0.04225352  0.95774648]
# Round 217 two large crickets meet  [  60 1366] [ 0.04207574  0.95792426]
# Round 218 two large crickets meet  [  60 1372] [ 0.04189944  0.95810056]
# Round 219 two large crickets meet  [  60 1378] [ 0.04172462  0.95827538]
# Round 220 two large crickets meet  [  60 1384] [ 0.04155125  0.95844875]
# Round 221 two large crickets meet  [  60 1390] [ 0.04137931  0.95862069]
# Round 222 two large crickets meet  [  60 1396] [ 0.04120879  0.95879121]
# Round 223 two large crickets meet  [  60 1402] [ 0.04103967  0.95896033]
# Round 224 two large crickets meet  [  60 1408] [ 0.04087193  0.95912807]
# Round 225 two large crickets meet  [  60 1414] [ 0.04070556  0.95929444]
# Round 226 two large crickets meet  [  60 1420] [ 0.04054054  0.95945946]
# Round 227 two large crickets meet  [  60 1426] [ 0.04037685  0.95962315]
# Round 228 two large crickets meet  [  60 1432] [ 0.04021448  0.95978552]
# Round 229 a small meets a large    [  61 1440] [ 0.04063957  0.95936043]
# Round 230 two large crickets meet  [  61 1446] [ 0.04047777  0.95952223]
# Round 231 two large crickets meet  [  61 1452] [ 0.04031725  0.95968275]
# Round 232 two large crickets meet  [  61 1458] [ 0.040158  0.959842]
# Round 233 two large crickets meet  [  61 1464] [ 0.04  0.96]
# Round 234 two large crickets meet  [  61 1470] [ 0.03984324  0.96015676]
# Round 235 two large crickets meet  [  61 1476] [ 0.0396877  0.9603123]
# Round 236 two large crickets meet  [  61 1482] [ 0.03953338  0.96046662]
# Round 237 two large crickets meet  [  61 1488] [ 0.03938025  0.96061975]
# Round 238 two large crickets meet  [  61 1494] [ 0.0392283  0.9607717]
# Round 239 two large crickets meet  [  61 1500] [ 0.03907751  0.96092249]
# Round 240 two large crickets meet  [  61 1506] [ 0.03892789  0.96107211]
# Round 241 two large crickets meet  [  61 1512] [ 0.0387794  0.9612206]
# Round 242 two large crickets meet  [  61 1518] [ 0.03863205  0.96136795]
# Round 243 two large crickets meet  [  61 1524] [ 0.0384858  0.9615142]
# Round 244 two large crickets meet  [  61 1530] [ 0.03834067  0.96165933]
# Round 245 two large crickets meet  [  61 1536] [ 0.03819662  0.96180338]
# Round 246 a small meets a large    [  62 1544] [ 0.03860523  0.96139477]
# Round 247 two large crickets meet  [  62 1550] [ 0.03846154  0.96153846]
# Round 248 two large crickets meet  [  62 1556] [ 0.03831891  0.96168109]
# Round 249 two large crickets meet  [  62 1562] [ 0.03817734  0.96182266]
# Round 250 two large crickets meet  [  62 1568] [ 0.03803681  0.96196319]
# Round 251 two large crickets meet  [  62 1574] [ 0.03789731  0.96210269]
# Round 252 two large crickets meet  [  62 1580] [ 0.03775883  0.96224117]
# Round 253 two large crickets meet  [  62 1586] [ 0.03762136  0.96237864]
# Round 254 two large crickets meet  [  62 1592] [ 0.03748489  0.96251511]
# Round 255 two large crickets meet  [  62 1598] [ 0.0373494  0.9626506]
# Round 256 two large crickets meet  [  62 1604] [ 0.03721489  0.96278511]
# Round 257 two large crickets meet  [  62 1610] [ 0.03708134  0.96291866]
# Round 258 two large crickets meet  [  62 1616] [ 0.03694875  0.96305125]
# Round 259 two large crickets meet  [  62 1622] [ 0.0368171  0.9631829]
# Round 260 two large crickets meet  [  62 1628] [ 0.03668639  0.96331361]
# Round 261 two large crickets meet  [  62 1634] [ 0.0365566  0.9634434]
# Round 262 two large crickets meet  [  62 1640] [ 0.03642773  0.96357227]
# Round 263 two large crickets meet  [  62 1646] [ 0.03629977  0.96370023]
# Round 264 two large crickets meet  [  62 1652] [ 0.0361727  0.9638273]
# Round 265 two large crickets meet  [  62 1658] [ 0.03604651  0.96395349]
# Round 266 two large crickets meet  [  62 1664] [ 0.03592121  0.96407879]
# Round 267 two large crickets meet  [  62 1670] [ 0.03579677  0.96420323]
# Round 268 two large crickets meet  [  62 1676] [ 0.03567319  0.96432681]
# Round 269 two large crickets meet  [  62 1682] [ 0.03555046  0.96444954]
# Round 270 two large crickets meet  [  62 1688] [ 0.03542857  0.96457143]
# Round 271 two large crickets meet  [  62 1694] [ 0.03530752  0.96469248]
# Round 272 two large crickets meet  [  62 1700] [ 0.03518729  0.96481271]
# Round 273 two large crickets meet  [  62 1706] [ 0.03506787  0.96493213]
# Round 274 two large crickets meet  [  62 1712] [ 0.03494927  0.96505073]
# Round 275 two large crickets meet  [  62 1718] [ 0.03483146  0.96516854]
# Round 276 a small meets a large    [  63 1726] [ 0.0352152  0.9647848]
# Round 277 two large crickets meet  [  63 1732] [ 0.03509749  0.96490251]
# Round 278 two large crickets meet  [  63 1738] [ 0.03498057  0.96501943]
# Round 279 two large crickets meet  [  63 1744] [ 0.03486442  0.96513558]
# Round 280 two large crickets meet  [  63 1750] [ 0.03474903  0.96525097]
# Round 281 two large crickets meet  [  63 1756] [ 0.03463441  0.96536559]
# Round 282 two large crickets meet  [  63 1762] [ 0.03452055  0.96547945]
# Round 283 two large crickets meet  [  63 1768] [ 0.03440743  0.96559257]
# Round 284 two large crickets meet  [  63 1774] [ 0.03429505  0.96570495]
# Round 285 two large crickets meet  [  63 1780] [ 0.0341834  0.9658166]
# Round 286 two large crickets meet  [  63 1786] [ 0.03407247  0.96592753]
# Round 287 two large crickets meet  [  63 1792] [ 0.03396226  0.96603774]
# Round 288 two large crickets meet  [  63 1798] [ 0.03385277  0.96614723]
# Round 289 two large crickets meet  [  63 1804] [ 0.03374397  0.96625603]
# Round 290 two large crickets meet  [  63 1810] [ 0.03363588  0.96636412]
# Round 291 two large crickets meet  [  63 1816] [ 0.03352847  0.96647153]
# Round 292 two large crickets meet  [  63 1822] [ 0.03342175  0.96657825]
# Round 293 two large crickets meet  [  63 1828] [ 0.03331571  0.96668429]
# Round 294 two large crickets meet  [  63 1834] [ 0.03321033  0.96678967]
# Round 295 two large crickets meet  [  63 1840] [ 0.03310562  0.96689438]
# Round 296 two large crickets meet  [  63 1846] [ 0.03300157  0.96699843]
# Round 297 two large crickets meet  [  63 1852] [ 0.03289817  0.96710183]
# Round 298 two large crickets meet  [  63 1858] [ 0.03279542  0.96720458]
# Round 299 two large crickets meet  [  63 1864] [ 0.03269331  0.96730669]
# Round 300 two large crickets meet  [  63 1870] [ 0.03259183  0.96740817]
# Round 301 two large crickets meet  [  63 1876] [ 0.03249097  0.96750903]
# Round 302 two large crickets meet  [  63 1882] [ 0.03239075  0.96760925]
# Round 303 two large crickets meet  [  63 1888] [ 0.03229113  0.96770887]
# Round 304 two large crickets meet  [  63 1894] [ 0.03219213  0.96780787]
# Round 305 two large crickets meet  [  63 1900] [ 0.03209373  0.96790627]
# Round 306 two large crickets meet  [  63 1906] [ 0.03199594  0.96800406]
# Round 307 two large crickets meet  [  63 1912] [ 0.03189873  0.96810127]
# Round 308 two large crickets meet  [  63 1918] [ 0.03180212  0.96819788]
# Round 309 two large crickets meet  [  63 1924] [ 0.03170609  0.96829391]
# Round 310 two large crickets meet  [  63 1930] [ 0.03161064  0.96838936]
# Round 311 two large crickets meet  [  63 1936] [ 0.03151576  0.96848424]
# Round 312 two large crickets meet  [  63 1942] [ 0.03142145  0.96857855]
# Round 313 two large crickets meet  [  63 1948] [ 0.0313277  0.9686723]
# Round 314 two large crickets meet  [  63 1954] [ 0.03123451  0.96876549]
# Round 315 two large crickets meet  [  63 1960] [ 0.03114187  0.96885813]
# Round 316 two large crickets meet  [  63 1966] [ 0.03104978  0.96895022]
# Round 317 two large crickets meet  [  63 1972] [ 0.03095823  0.96904177]
# Round 318 two large crickets meet  [  63 1978] [ 0.03086722  0.96913278]
# Round 319 two large crickets meet  [  63 1984] [ 0.03077675  0.96922325]
# Round 320 two large crickets meet  [  63 1990] [ 0.0306868  0.9693132]
# Round 321 two large crickets meet  [  63 1996] [ 0.03059738  0.96940262]
# Round 322 two large crickets meet  [  63 2002] [ 0.03050847  0.96949153]
# Round 323 two large crickets meet  [  63 2008] [ 0.03042009  0.96957991]
# Round 324 two large crickets meet  [  63 2014] [ 0.03033221  0.96966779]
# Round 325 two large crickets meet  [  63 2020] [ 0.03024484  0.96975516]
# Round 326 two large crickets meet  [  63 2026] [ 0.03015797  0.96984203]
# Round 327 two large crickets meet  [  63 2032] [ 0.0300716  0.9699284]
# Round 328 two large crickets meet  [  63 2038] [ 0.02998572  0.97001428]
# Round 329 two large crickets meet  [  63 2044] [ 0.02990033  0.97009967]
# Round 330 two large crickets meet  [  63 2050] [ 0.02981543  0.97018457]
# Round 331 two large crickets meet  [  63 2056] [ 0.02973101  0.97026899]
# Round 332 a small meets a large    [  64 2064] [ 0.03007519  0.96992481]
# Round 333 two large crickets meet  [  64 2070] [ 0.02999063  0.97000937]
# Round 334 two large crickets meet  [  64 2076] [ 0.02990654  0.97009346]
# Round 335 two large crickets meet  [  64 2082] [ 0.02982293  0.97017707]
# Round 336 a small meets a large    [  65 2090] [ 0.03016241  0.96983759]
# Round 337 two large crickets meet  [  65 2096] [ 0.03007867  0.96992133]
# Round 338 two large crickets meet  [  65 2102] [ 0.02999539  0.97000461]
# Round 339 two large crickets meet  [  65 2108] [ 0.02991256  0.97008744]
# Round 340 two large crickets meet  [  65 2114] [ 0.0298302  0.9701698]
# Round 341 two large crickets meet  [  65 2120] [ 0.02974828  0.97025172]
# Round 342 two large crickets meet  [  65 2126] [ 0.02966682  0.97033318]
# Round 343 two large crickets meet  [  65 2132] [ 0.0295858  0.9704142]
# Round 344 two large crickets meet  [  65 2138] [ 0.02950522  0.97049478]
# Round 345 two large crickets meet  [  65 2144] [ 0.02942508  0.97057492]
# Round 346 two large crickets meet  [  65 2150] [ 0.02934537  0.97065463]
# Round 347 two large crickets meet  [  65 2156] [ 0.0292661  0.9707339]
# Round 348 a small meets a large    [  66 2164] [ 0.02959641  0.97040359]
# Round 349 two large crickets meet  [  66 2170] [ 0.02951699  0.97048301]
# Round 350 two large crickets meet  [  66 2176] [ 0.029438  0.970562]
# Round 351 two large crickets meet  [  66 2182] [ 0.02935943  0.97064057]
# Round 352 two large crickets meet  [  66 2188] [ 0.02928128  0.97071872]
# Round 353 a small meets a large    [  67 2196] [ 0.02960672  0.97039328]
# Round 354 two large crickets meet  [  67 2202] [ 0.02952843  0.97047157]
# Round 355 two large crickets meet  [  67 2208] [ 0.02945055  0.97054945]
# Round 356 two large crickets meet  [  67 2214] [ 0.02937308  0.97062692]
# Round 357 two large crickets meet  [  67 2220] [ 0.02929602  0.97070398]
# Round 358 two large crickets meet  [  67 2226] [ 0.02921936  0.97078064]
# Round 359 two large crickets meet  [  67 2232] [ 0.02914311  0.97085689]
# Round 360 two large crickets meet  [  67 2238] [ 0.02906725  0.97093275]
# Round 361 two large crickets meet  [  67 2244] [ 0.02899178  0.97100822]
# Round 362 two large crickets meet  [  67 2250] [ 0.0289167  0.9710833]
# Round 363 two large crickets meet  [  67 2256] [ 0.02884201  0.97115799]
# Round 364 two large crickets meet  [  67 2262] [ 0.02876771  0.97123229]
# Round 365 two large crickets meet  [  67 2268] [ 0.02869379  0.97130621]
# Round 366 two large crickets meet  [  67 2274] [ 0.02862025  0.97137975]
# Round 367 two large crickets meet  [  67 2280] [ 0.02854708  0.97145292]
# Round 368 two large crickets meet  [  67 2286] [ 0.02847429  0.97152571]
# Round 369 two large crickets meet  [  67 2292] [ 0.02840187  0.97159813]
# Round 370 two large crickets meet  [  67 2298] [ 0.02832981  0.97167019]
# Round 371 two large crickets meet  [  67 2304] [ 0.02825812  0.97174188]
# Round 372 two large crickets meet  [  67 2310] [ 0.02818679  0.97181321]
# Round 373 two large crickets meet  [  67 2316] [ 0.02811582  0.97188418]
# Round 374 two large crickets meet  [  67 2322] [ 0.02804521  0.97195479]
# Round 375 two large crickets meet  [  67 2328] [ 0.02797495  0.97202505]
# Round 376 two large crickets meet  [  67 2334] [ 0.02790504  0.97209496]
# Round 377 two large crickets meet  [  67 2340] [ 0.02783548  0.97216452]
# Round 378 two large crickets meet  [  67 2346] [ 0.02776627  0.97223373]
# Round 379 two large crickets meet  [  67 2352] [ 0.0276974  0.9723026]
# Round 380 two large crickets meet  [  67 2358] [ 0.02762887  0.97237113]
# Round 381 two large crickets meet  [  67 2364] [ 0.02756067  0.97243933]
# Round 382 two large crickets meet  [  67 2370] [ 0.02749282  0.97250718]
# Round 383 two large crickets meet  [  67 2376] [ 0.0274253  0.9725747]
# Round 384 two large crickets meet  [  67 2382] [ 0.02735811  0.97264189]
# Round 385 two large crickets meet  [  67 2388] [ 0.02729124  0.97270876]
# Round 386 two large crickets meet  [  67 2394] [ 0.02722471  0.97277529]
# Round 387 two large crickets meet  [  67 2400] [ 0.02715849  0.97284151]
# Round 388 two large crickets meet  [  67 2406] [ 0.0270926  0.9729074]
# Round 389 two large crickets meet  [  67 2412] [ 0.02702703  0.97297297]
# Round 390 a small meets a large    [  68 2420] [ 0.02733119  0.97266881]
# Round 391 two large crickets meet  [  68 2426] [ 0.02726544  0.97273456]
# Round 392 two large crickets meet  [  68 2432] [ 0.0272  0.9728]
# Round 393 two large crickets meet  [  68 2438] [ 0.02713488  0.97286512]
# Round 394 two large crickets meet  [  68 2444] [ 0.02707006  0.97292994]
# Round 395 two large crickets meet  [  68 2450] [ 0.02700556  0.97299444]
# Round 396 two large crickets meet  [  68 2456] [ 0.02694136  0.97305864]
# Round 397 two large crickets meet  [  68 2462] [ 0.02687747  0.97312253]
# Round 398 two large crickets meet  [  68 2468] [ 0.02681388  0.97318612]
# Round 399 two large crickets meet  [  68 2474] [ 0.02675059  0.97324941]
# Round 400 two large crickets meet  [  68 2480] [ 0.0266876  0.9733124]
# Round 401 two large crickets meet  [  68 2486] [ 0.0266249  0.9733751]
# Round 402 two large crickets meet  [  68 2492] [ 0.0265625  0.9734375]
# Round 403 two large crickets meet  [  68 2498] [ 0.02650039  0.97349961]
# Round 404 two large crickets meet  [  68 2504] [ 0.02643857  0.97356143]
# Round 405 two large crickets meet  [  68 2510] [ 0.02637704  0.97362296]
# Round 406 two large crickets meet  [  68 2516] [ 0.02631579  0.97368421]
# Round 407 two large crickets meet  [  68 2522] [ 0.02625483  0.97374517]
# Round 408 two large crickets meet  [  68 2528] [ 0.02619414  0.97380586]
# Round 409 two large crickets meet  [  68 2534] [ 0.02613374  0.97386626]
# Round 410 two large crickets meet  [  68 2540] [ 0.02607362  0.97392638]
# Round 411 two large crickets meet  [  68 2546] [ 0.02601377  0.97398623]
# Round 412 two large crickets meet  [  68 2552] [ 0.0259542  0.9740458]
# Round 413 two large crickets meet  [  68 2558] [ 0.0258949  0.9741051]
# Round 414 two large crickets meet  [  68 2564] [ 0.02583587  0.97416413]
# Round 415 two large crickets meet  [  68 2570] [ 0.0257771  0.9742229]
# Round 416 two large crickets meet  [  68 2576] [ 0.02571861  0.97428139]
# Round 417 two large crickets meet  [  68 2582] [ 0.02566038  0.97433962]
# Round 418 two large crickets meet  [  68 2588] [ 0.02560241  0.97439759]
# Round 419 two large crickets meet  [  68 2594] [ 0.0255447  0.9744553]
# Round 420 two large crickets meet  [  68 2600] [ 0.02548726  0.97451274]
# Round 421 two large crickets meet  [  68 2606] [ 0.02543007  0.97456993]
# Round 422 two large crickets meet  [  68 2612] [ 0.02537313  0.97462687]
# Round 423 two large crickets meet  [  68 2618] [ 0.02531646  0.97468354]
# Round 424 two large crickets meet  [  68 2624] [ 0.02526003  0.97473997]
# Round 425 two large crickets meet  [  68 2630] [ 0.02520385  0.97479615]
# Round 426 two large crickets meet  [  68 2636] [ 0.02514793  0.97485207]
# Round 427 two large crickets meet  [  68 2642] [ 0.02509225  0.97490775]
# Round 428 two large crickets meet  [  68 2648] [ 0.02503682  0.97496318]
# Round 429 two large crickets meet  [  68 2654] [ 0.02498163  0.97501837]
# Round 430 two large crickets meet  [  68 2660] [ 0.02492669  0.97507331]
# Round 431 two large crickets meet  [  68 2666] [ 0.02487198  0.97512802]
# Round 432 two large crickets meet  [  68 2672] [ 0.02481752  0.97518248]
# Round 433 two large crickets meet  [  68 2678] [ 0.02476329  0.97523671]
# Round 434 two large crickets meet  [  68 2684] [ 0.0247093  0.9752907]
# Round 435 two large crickets meet  [  68 2690] [ 0.02465555  0.97534445]
# Round 436 two large crickets meet  [  68 2696] [ 0.02460203  0.97539797]
# Round 437 two large crickets meet  [  68 2702] [ 0.02454874  0.97545126]
# Round 438 two large crickets meet  [  68 2708] [ 0.02449568  0.97550432]
# Round 439 two large crickets meet  [  68 2714] [ 0.02444285  0.97555715]
# Round 440 two large crickets meet  [  68 2720] [ 0.02439024  0.97560976]
# Round 441 two large crickets meet  [  68 2726] [ 0.02433787  0.97566213]
# Round 442 a small meets a large    [  69 2734] [ 0.02461648  0.97538352]
# Round 443 two large crickets meet  [  69 2740] [ 0.0245639  0.9754361]
# Round 444 two large crickets meet  [  69 2746] [ 0.02451155  0.97548845]
# Round 445 two large crickets meet  [  69 2752] [ 0.02445941  0.97554059]
# Round 446 two large crickets meet  [  69 2758] [ 0.0244075  0.9755925]
# Round 447 two large crickets meet  [  69 2764] [ 0.02435581  0.97564419]
# Round 448 two large crickets meet  [  69 2770] [ 0.02430433  0.97569567]
# Round 449 two large crickets meet  [  69 2776] [ 0.02425308  0.97574692]
# Round 450 two large crickets meet  [  69 2782] [ 0.02420203  0.97579797]
# Round 451 a small meets a large    [  70 2790] [ 0.02447552  0.97552448]
# Round 452 two large crickets meet  [  70 2796] [ 0.02442428  0.97557572]
# Round 453 two large crickets meet  [  70 2802] [ 0.02437326  0.97562674]
# Round 454 two large crickets meet  [  70 2808] [ 0.02432245  0.97567755]
# Round 455 two large crickets meet  [  70 2814] [ 0.02427184  0.97572816]
# Round 456 two large crickets meet  [  70 2820] [ 0.02422145  0.97577855]
# Round 457 two large crickets meet  [  70 2826] [ 0.02417127  0.97582873]
# Round 458 two large crickets meet  [  70 2832] [ 0.0241213  0.9758787]
# Round 459 two large crickets meet  [  70 2838] [ 0.02407153  0.97592847]
# Round 460 two large crickets meet  [  70 2844] [ 0.02402196  0.97597804]
# Round 461 two large crickets meet  [  70 2850] [ 0.0239726  0.9760274]
# Round 462 two large crickets meet  [  70 2856] [ 0.02392344  0.97607656]
# Round 463 two large crickets meet  [  70 2862] [ 0.02387449  0.97612551]
# Round 464 two large crickets meet  [  70 2868] [ 0.02382573  0.97617427]
# Round 465 two large crickets meet  [  70 2874] [ 0.02377717  0.97622283]
# Round 466 two large crickets meet  [  70 2880] [ 0.02372881  0.97627119]
# Round 467 two large crickets meet  [  70 2886] [ 0.02368065  0.97631935]
# Round 468 two large crickets meet  [  70 2892] [ 0.02363268  0.97636732]
# Round 469 two large crickets meet  [  70 2898] [ 0.02358491  0.97641509]
# Round 470 two large crickets meet  [  70 2904] [ 0.02353732  0.97646268]
# Round 471 two large crickets meet  [  70 2910] [ 0.02348993  0.97651007]
# Round 472 two large crickets meet  [  70 2916] [ 0.02344273  0.97655727]
# Round 473 two large crickets meet  [  70 2922] [ 0.02339572  0.97660428]
# Round 474 two large crickets meet  [  70 2928] [ 0.0233489  0.9766511]
# Round 475 two large crickets meet  [  70 2934] [ 0.02330226  0.97669774]
# Round 476 two large crickets meet  [  70 2940] [ 0.02325581  0.97674419]
# Round 477 two large crickets meet  [  70 2946] [ 0.02320955  0.97679045]
# Round 478 two large crickets meet  [  70 2952] [ 0.02316347  0.97683653]
# Round 479 two large crickets meet  [  70 2958] [ 0.02311757  0.97688243]
# Round 480 two large crickets meet  [  70 2964] [ 0.02307185  0.97692815]
# Round 481 two large crickets meet  [  70 2970] [ 0.02302632  0.97697368]
# Round 482 two large crickets meet  [  70 2976] [ 0.02298096  0.97701904]
# Round 483 two large crickets meet  [  70 2982] [ 0.02293578  0.97706422]
# Round 484 two large crickets meet  [  70 2988] [ 0.02289078  0.97710922]
# Round 485 two large crickets meet  [  70 2994] [ 0.02284595  0.97715405]
# Round 486 a small meets a large    [  71 3002] [ 0.02310446  0.97689554]
# Round 487 two large crickets meet  [  71 3008] [ 0.02305943  0.97694057]
# Round 488 two large crickets meet  [  71 3014] [ 0.02301459  0.97698541]
# Round 489 two large crickets meet  [  71 3020] [ 0.02296991  0.97703009]
# Round 490 two large crickets meet  [  71 3026] [ 0.02292541  0.97707459]
# Round 491 two large crickets meet  [  71 3032] [ 0.02288108  0.97711892]
# Round 492 two large crickets meet  [  71 3038] [ 0.02283693  0.97716307]
# Round 493 two large crickets meet  [  71 3044] [ 0.02279294  0.97720706]
# Round 494 two large crickets meet  [  71 3050] [ 0.02274912  0.97725088]
# Round 495 two large crickets meet  [  71 3056] [ 0.02270547  0.97729453]
# Round 496 two large crickets meet  [  71 3062] [ 0.02266199  0.97733801]
# Round 497 two large crickets meet  [  71 3068] [ 0.02261867  0.97738133]
# Round 498 two large crickets meet  [  71 3074] [ 0.02257552  0.97742448]
# Round 499 two large crickets meet  [  71 3080] [ 0.02253253  0.97746747]
# Round 500 two large crickets meet  [  71 3086] [ 0.02248971  0.97751029]
# Round 501 two large crickets meet  [  71 3092] [ 0.02244704  0.97755296]
# Round 502 two large crickets meet  [  71 3098] [ 0.02240454  0.97759546]
# Round 503 two large crickets meet  [  71 3104] [ 0.0223622  0.9776378]
# Round 504 two large crickets meet  [  71 3110] [ 0.02232003  0.97767997]
# Round 505 two large crickets meet  [  71 3116] [ 0.022278  0.977722]
# Round 506 two large crickets meet  [  71 3122] [ 0.02223614  0.97776386]
# Round 507 two large crickets meet  [  71 3128] [ 0.02219444  0.97780556]
# Round 508 two large crickets meet  [  71 3134] [ 0.02215289  0.97784711]
# Round 509 two large crickets meet  [  71 3140] [ 0.02211149  0.97788851]
# Round 510 two large crickets meet  [  71 3146] [ 0.02207025  0.97792975]
# Round 511 two large crickets meet  [  71 3152] [ 0.02202917  0.97797083]
# Round 512 a small meets a large    [  72 3160] [ 0.02227723  0.97772277]
# Round 513 two large crickets meet  [  72 3166] [ 0.02223595  0.97776405]
# Round 514 two large crickets meet  [  72 3172] [ 0.02219482  0.97780518]
# Round 515 two large crickets meet  [  72 3178] [ 0.02215385  0.97784615]
# Round 516 two large crickets meet  [  72 3184] [ 0.02211302  0.97788698]
# Round 517 two large crickets meet  [  72 3190] [ 0.02207235  0.97792765]
# Round 518 two large crickets meet  [  72 3196] [ 0.02203182  0.97796818]
# Round 519 two large crickets meet  [  72 3202] [ 0.02199145  0.97800855]
# Round 520 two large crickets meet  [  72 3208] [ 0.02195122  0.97804878]
# Round 521 two large crickets meet  [  72 3214] [ 0.02191114  0.97808886]
# Round 522 two large crickets meet  [  72 3220] [ 0.0218712  0.9781288]
# Round 523 two large crickets meet  [  72 3226] [ 0.02183141  0.97816859]
# Round 524 two large crickets meet  [  72 3232] [ 0.02179177  0.97820823]
# Round 525 two large crickets meet  [  72 3238] [ 0.02175227  0.97824773]
# Round 526 two large crickets meet  [  72 3244] [ 0.02171291  0.97828709]
# Round 527 two large crickets meet  [  72 3250] [ 0.02167369  0.97832631]
# Round 528 two large crickets meet  [  72 3256] [ 0.02163462  0.97836538]
# Round 529 a small meets a large    [  73 3264] [ 0.02187594  0.97812406]
# Round 530 a small meets a large    [  74 3272] [ 0.02211596  0.97788404]
# Round 531 two large crickets meet  [  74 3278] [ 0.02207637  0.97792363]
# Round 532 two large crickets meet  [  74 3284] [ 0.02203693  0.97796307]
# Round 533 two large crickets meet  [  74 3290] [ 0.02199762  0.97800238]
# Round 534 two large crickets meet  [  74 3296] [ 0.02195846  0.97804154]
# Round 535 two large crickets meet  [  74 3302] [ 0.02191943  0.97808057]
# Round 536 two large crickets meet  [  74 3308] [ 0.02188054  0.97811946]
# Round 537 two large crickets meet  [  74 3314] [ 0.02184179  0.97815821]
# Round 538 two large crickets meet  [  74 3320] [ 0.02180318  0.97819682]
# Round 539 two large crickets meet  [  74 3326] [ 0.02176471  0.97823529]
# Round 540 two large crickets meet  [  74 3332] [ 0.02172637  0.97827363]
# Round 541 two large crickets meet  [  74 3338] [ 0.02168816  0.97831184]
# Round 542 two large crickets meet  [  74 3344] [ 0.02165009  0.97834991]
# Round 543 two large crickets meet  [  74 3350] [ 0.02161215  0.97838785]
# Round 544 two large crickets meet  [  74 3356] [ 0.02157434  0.97842566]
# Round 545 two large crickets meet  [  74 3362] [ 0.02153667  0.97846333]
# Round 546 two large crickets meet  [  74 3368] [ 0.02149913  0.97850087]
# Round 547 two large crickets meet  [  74 3374] [ 0.02146172  0.97853828]
# Round 548 two large crickets meet  [  74 3380] [ 0.02142444  0.97857556]
# Round 549 two large crickets meet  [  74 3386] [ 0.02138728  0.97861272]
# Round 550 two large crickets meet  [  74 3392] [ 0.02135026  0.97864974]
# Round 551 two large crickets meet  [  74 3398] [ 0.02131336  0.97868664]
# Round 552 two large crickets meet  [  74 3404] [ 0.0212766  0.9787234]
# Round 553 two large crickets meet  [  74 3410] [ 0.02123995  0.97876005]
# Round 554 two large crickets meet  [  74 3416] [ 0.02120344  0.97879656]
# Round 555 two large crickets meet  [  74 3422] [ 0.02116705  0.97883295]
# Round 556 two large crickets meet  [  74 3428] [ 0.02113078  0.97886922]
# Round 557 two large crickets meet  [  74 3434] [ 0.02109464  0.97890536]
# Round 558 two large crickets meet  [  74 3440] [ 0.02105862  0.97894138]
# Round 559 two large crickets meet  [  74 3446] [ 0.02102273  0.97897727]
# Round 560 two large crickets meet  [  74 3452] [ 0.02098695  0.97901305]
# Round 561 two large crickets meet  [  74 3458] [ 0.0209513  0.9790487]
# Round 562 two large crickets meet  [  74 3464] [ 0.02091577  0.97908423]
# Round 563 two large crickets meet  [  74 3470] [ 0.02088036  0.97911964]
# Round 564 two large crickets meet  [  74 3476] [ 0.02084507  0.97915493]
# Round 565 two large crickets meet  [  74 3482] [ 0.0208099  0.9791901]
# Round 566 two large crickets meet  [  74 3488] [ 0.02077485  0.97922515]
# Round 567 two large crickets meet  [  74 3494] [ 0.02073991  0.97926009]
# Round 568 two large crickets meet  [  74 3500] [ 0.02070509  0.97929491]
# Round 569 two large crickets meet  [  74 3506] [ 0.02067039  0.97932961]
# Round 570 two large crickets meet  [  74 3512] [ 0.02063581  0.97936419]
# Round 571 two large crickets meet  [  74 3518] [ 0.02060134  0.97939866]
# Round 572 two large crickets meet  [  74 3524] [ 0.02056698  0.97943302]
# Round 573 two large crickets meet  [  74 3530] [ 0.02053274  0.97946726]
# Round 574 two large crickets meet  [  74 3536] [ 0.02049861  0.97950139]
# Round 575 two large crickets meet  [  74 3542] [ 0.0204646  0.9795354]
# Round 576 two large crickets meet  [  74 3548] [ 0.0204307  0.9795693]
# Round 577 two large crickets meet  [  74 3554] [ 0.02039691  0.97960309]
# Round 578 two large crickets meet  [  74 3560] [ 0.02036324  0.97963676]
# Round 579 two large crickets meet  [  74 3566] [ 0.02032967  0.97967033]
# Round 580 two large crickets meet  [  74 3572] [ 0.02029622  0.97970378]
# Round 581 two large crickets meet  [  74 3578] [ 0.02026287  0.97973713]
# Round 582 two large crickets meet  [  74 3584] [ 0.02022963  0.97977037]
# Round 583 two large crickets meet  [  74 3590] [ 0.02019651  0.97980349]
# Round 584 two large crickets meet  [  74 3596] [ 0.02016349  0.97983651]
# Round 585 two large crickets meet  [  74 3602] [ 0.02013058  0.97986942]
# Round 586 two large crickets meet  [  74 3608] [ 0.02009777  0.97990223]
# Round 587 two large crickets meet  [  74 3614] [ 0.02006508  0.97993492]
# Round 588 two large crickets meet  [  74 3620] [ 0.02003249  0.97996751]
# Round 589 two large crickets meet  [  74 3626] [ 0.02  0.98]
# Round 590 two large crickets meet  [  74 3632] [ 0.01996762  0.98003238]
# Round 591 two large crickets meet  [  74 3638] [ 0.01993534  0.98006466]
# Round 592 two large crickets meet  [  74 3644] [ 0.01990317  0.98009683]
# Round 593 two large crickets meet  [  74 3650] [ 0.01987111  0.98012889]
# Round 594 two large crickets meet  [  74 3656] [ 0.01983914  0.98016086]
# Round 595 two large crickets meet  [  74 3662] [ 0.01980728  0.98019272]
# Round 596 two large crickets meet  [  74 3668] [ 0.01977552  0.98022448]
# Round 597 a small meets a large    [  75 3676] [ 0.01999467  0.98000533]
# Round 598 two large crickets meet  [  75 3682] [ 0.01996274  0.98003726]
# Round 599 two large crickets meet  [  75 3688] [ 0.01993091  0.98006909]
# Round 600 two large crickets meet  [  75 3694] [ 0.01989918  0.98010082]
# Round 601 two large crickets meet  [  75 3700] [ 0.01986755  0.98013245]
# Round 602 two large crickets meet  [  75 3706] [ 0.01983602  0.98016398]
# Round 603 two large crickets meet  [  75 3712] [ 0.01980459  0.98019541]
# Round 604 two large crickets meet  [  75 3718] [ 0.01977327  0.98022673]
# Round 605 two large crickets meet  [  75 3724] [ 0.01974204  0.98025796]
# Round 606 two large crickets meet  [  75 3730] [ 0.01971091  0.98028909]
# Round 607 two large crickets meet  [  75 3736] [ 0.01967987  0.98032013]
# Round 608 two large crickets meet  [  75 3742] [ 0.01964894  0.98035106]
# Round 609 two large crickets meet  [  75 3748] [ 0.0196181  0.9803819]
# Round 610 two large crickets meet  [  75 3754] [ 0.01958736  0.98041264]
# Round 611 two large crickets meet  [  75 3760] [ 0.01955671  0.98044329]
# Round 612 two large crickets meet  [  75 3766] [ 0.01952617  0.98047383]
# Round 613 two large crickets meet  [  75 3772] [ 0.01949571  0.98050429]
# Round 614 two large crickets meet  [  75 3778] [ 0.01946535  0.98053465]
# Round 615 two large crickets meet  [  75 3784] [ 0.01943509  0.98056491]
# Round 616 two large crickets meet  [  75 3790] [ 0.01940492  0.98059508]
# Round 617 two large crickets meet  [  75 3796] [ 0.01937484  0.98062516]
# Round 618 two large crickets meet  [  75 3802] [ 0.01934485  0.98065515]
# Round 619 two large crickets meet  [  75 3808] [ 0.01931496  0.98068504]
# Round 620 two large crickets meet  [  75 3814] [ 0.01928516  0.98071484]
# Round 621 two large crickets meet  [  75 3820] [ 0.01925546  0.98074454]
# Round 622 two large crickets meet  [  75 3826] [ 0.01922584  0.98077416]
# Round 623 two large crickets meet  [  75 3832] [ 0.01919631  0.98080369]
# Round 624 two large crickets meet  [  75 3838] [ 0.01916688  0.98083312]
# Round 625 a small meets a large    [  76 3846] [ 0.01937787  0.98062213]
# Round 626 two large crickets meet  [  76 3852] [ 0.01934827  0.98065173]
# Round 627 two large crickets meet  [  76 3858] [ 0.01931876  0.98068124]
# Round 628 a small meets a large    [  77 3866] [ 0.01952828  0.98047172]
# Round 629 two large crickets meet  [  77 3872] [ 0.01949861  0.98050139]
# Round 630 two large crickets meet  [  77 3878] [ 0.01946903  0.98053097]
# Round 631 two large crickets meet  [  77 3884] [ 0.01943954  0.98056046]
# Round 632 two large crickets meet  [  77 3890] [ 0.01941013  0.98058987]
# Round 633 two large crickets meet  [  77 3896] [ 0.01938082  0.98061918]
# Round 634 two large crickets meet  [  77 3902] [ 0.0193516  0.9806484]
# Round 635 two large crickets meet  [  77 3908] [ 0.01932246  0.98067754]
# Round 636 two large crickets meet  [  77 3914] [ 0.01929341  0.98070659]
# Round 637 two large crickets meet  [  77 3920] [ 0.01926445  0.98073555]
# Round 638 two large crickets meet  [  77 3926] [ 0.01923557  0.98076443]
# Round 639 two large crickets meet  [  77 3932] [ 0.01920678  0.98079322]
# Round 640 a small meets a large    [  78 3940] [ 0.01941264  0.98058736]
# Round 641 two large crickets meet  [  78 3946] [ 0.0193837  0.9806163]
# Round 642 two large crickets meet  [  78 3952] [ 0.01935484  0.98064516]
# Round 643 a small meets a large    [  79 3960] [ 0.0195593  0.9804407]
# Round 644 two large crickets meet  [  79 3966] [ 0.01953028  0.98046972]
# Round 645 two large crickets meet  [  79 3972] [ 0.01950136  0.98049864]
# Round 646 two large crickets meet  [  79 3978] [ 0.01947252  0.98052748]
# Round 647 two large crickets meet  [  79 3984] [ 0.01944376  0.98055624]
# Round 648 two large crickets meet  [  79 3990] [ 0.01941509  0.98058491]
# Round 649 two large crickets meet  [  79 3996] [ 0.0193865  0.9806135]
# Round 650 two large crickets meet  [  79 4002] [ 0.019358  0.980642]
# Round 651 two large crickets meet  [  79 4008] [ 0.01932958  0.98067042]
# Round 652 two large crickets meet  [  79 4014] [ 0.01930125  0.98069875]
# Round 653 two large crickets meet  [  79 4020] [ 0.01927299  0.98072701]
# Round 654 two large crickets meet  [  79 4026] [ 0.01924482  0.98075518]
# Round 655 two large crickets meet  [  79 4032] [ 0.01921674  0.98078326]
# Round 656 two large crickets meet  [  79 4038] [ 0.01918873  0.98081127]
# Round 657 two large crickets meet  [  79 4044] [ 0.01916081  0.98083919]
# Round 658 two large crickets meet  [  79 4050] [ 0.01913296  0.98086704]
# Round 659 two large crickets meet  [  79 4056] [ 0.0191052  0.9808948]
# Round 660 two large crickets meet  [  79 4062] [ 0.01907752  0.98092248]
# Round 661 two large crickets meet  [  79 4068] [ 0.01904992  0.98095008]
# Round 662 two large crickets meet  [  79 4074] [ 0.01902239  0.98097761]
# Round 663 two large crickets meet  [  79 4080] [ 0.01899495  0.98100505]
# Round 664 two large crickets meet  [  79 4086] [ 0.01896759  0.98103241]
# Round 665 two large crickets meet  [  79 4092] [ 0.0189403  0.9810597]
# ...
# Round 782 two large crickets meet  [  83 4802] [ 0.01699079  0.98300921]
# Round 783 two large crickets meet  [  83 4808] [ 0.01696994  0.98303006]
# Round 784 two large crickets meet  [  83 4814] [ 0.01694915  0.98305085]
# Round 785 two large crickets meet  [  83 4820] [ 0.01692841  0.98307159]
# Round 786 two large crickets meet  [  83 4826] [ 0.01690772  0.98309228]
# Round 787 two large crickets meet  [  83 4832] [ 0.01688708  0.98311292]
# Round 788 two large crickets meet  [  83 4838] [ 0.01686649  0.98313351]
# Round 789 two large crickets meet  [  83 4844] [ 0.01684595  0.98315405]
# Round 790 two large crickets meet  [  83 4850] [ 0.01682546  0.98317454]
# Round 791 two large crickets meet  [  83 4856] [ 0.01680502  0.98319498]
# Round 792 two large crickets meet  [  83 4862] [ 0.01678463  0.98321537]
# Round 793 two large crickets meet  [  83 4868] [ 0.01676429  0.98323571]
# Round 794 two large crickets meet  [  83 4874] [ 0.016744  0.983256]
# Round 795 two large crickets meet  [  83 4880] [ 0.01672376  0.98327624]
# Round 796 two large crickets meet  [  83 4886] [ 0.01670356  0.98329644]
# Round 797 two large crickets meet  [  83 4892] [ 0.01668342  0.98331658]
# Round 798 two large crickets meet  [  83 4898] [ 0.01666332  0.98333668]
# Round 799 two large crickets meet  [  83 4904] [ 0.01664327  0.98335673]
# Round 800 two large crickets meet  [  83 4910] [ 0.01662327  0.98337673]
# Round 801 two large crickets meet  [  83 4916] [ 0.01660332  0.98339668]
# Round 802 two large crickets meet  [  83 4922] [ 0.01658342  0.98341658]
# Round 803 two large crickets meet  [  83 4928] [ 0.01656356  0.98343644]
# Round 804 two large crickets meet  [  83 4934] [ 0.01654375  0.98345625]
# Round 805 two large crickets meet  [  83 4940] [ 0.01652399  0.98347601]
# Round 806 two large crickets meet  [  83 4946] [ 0.01650428  0.98349572]
# Round 807 two large crickets meet  [  83 4952] [ 0.01648461  0.98351539]
# Round 808 two large crickets meet  [  83 4958] [ 0.01646499  0.98353501]
# Round 809 two large crickets meet  [  83 4964] [ 0.01644541  0.98355459]
# Round 810 two large crickets meet  [  83 4970] [ 0.01642589  0.98357411]
# Round 811 two large crickets meet  [  83 4976] [ 0.0164064  0.9835936]
# Round 812 two large crickets meet  [  83 4982] [ 0.01638697  0.98361303]
# Round 813 two large crickets meet  [  83 4988] [ 0.01636758  0.98363242]
# Round 814 two large crickets meet  [  83 4994] [ 0.01634824  0.98365176]
# Round 815 two large crickets meet  [  83 5000] [ 0.01632894  0.98367106]
# Round 816 two large crickets meet  [  83 5006] [ 0.01630969  0.98369031]
# Round 817 two large crickets meet  [  83 5012] [ 0.01629048  0.98370952]
# Round 818 two large crickets meet  [  83 5018] [ 0.01627132  0.98372868]
# Round 819 two large crickets meet  [  83 5024] [ 0.0162522  0.9837478]
# Round 820 two large crickets meet  [  83 5030] [ 0.01623313  0.98376687]
# Round 821 two large crickets meet  [  83 5036] [ 0.0162141  0.9837859]
# Round 822 two large crickets meet  [  83 5042] [ 0.01619512  0.98380488]
# Round 823 two large crickets meet  [  83 5048] [ 0.01617618  0.98382382]
# Round 824 two large crickets meet  [  83 5054] [ 0.01615729  0.98384271]
# Round 825 two large crickets meet  [  83 5060] [ 0.01613844  0.98386156]
# Round 826 two large crickets meet  [  83 5066] [ 0.01611963  0.98388037]
# Round 827 two large crickets meet  [  83 5072] [ 0.01610087  0.98389913]
# Round 828 two large crickets meet  [  83 5078] [ 0.01608215  0.98391785]
# Round 829 two large crickets meet  [  83 5084] [ 0.01606348  0.98393652]
# Round 830 two large crickets meet  [  83 5090] [ 0.01604485  0.98395515]
# Round 831 two large crickets meet  [  83 5096] [ 0.01602626  0.98397374]
# Round 832 two large crickets meet  [  83 5102] [ 0.01600771  0.98399229]
# Round 833 two large crickets meet  [  83 5108] [ 0.01598921  0.98401079]
# Round 834 two large crickets meet  [  83 5114] [ 0.01597075  0.98402925]
# Round 835 a small meets a large    [  84 5122] [ 0.01613523  0.98386477]
# Round 836 two large crickets meet  [  84 5128] [ 0.01611665  0.98388335]
# Round 837 two large crickets meet  [  84 5134] [ 0.01609812  0.98390188]
# Round 838 two large crickets meet  [  84 5140] [ 0.01607963  0.98392037]
# Round 839 two large crickets meet  [  84 5146] [ 0.01606119  0.98393881]
# Round 840 two large crickets meet  [  84 5152] [ 0.01604278  0.98395722]
# Round 841 two large crickets meet  [  84 5158] [ 0.01602442  0.98397558]
# Round 842 two large crickets meet  [  84 5164] [ 0.0160061  0.9839939]
# Round 843 two large crickets meet  [  84 5170] [ 0.01598782  0.98401218]
# Round 844 two large crickets meet  [  84 5176] [ 0.01596958  0.98403042]
# Round 845 two large crickets meet  [  84 5182] [ 0.01595139  0.98404861]
# Round 846 two large crickets meet  [  84 5188] [ 0.01593323  0.98406677]
# Round 847 two large crickets meet  [  84 5194] [ 0.01591512  0.98408488]
# Round 848 two large crickets meet  [  84 5200] [ 0.01589705  0.98410295]
# Round 849 two large crickets meet  [  84 5206] [ 0.01587902  0.98412098]
# Round 850 two large crickets meet  [  84 5212] [ 0.01586103  0.98413897]
# Round 851 two large crickets meet  [  84 5218] [ 0.01584308  0.98415692]
# Round 852 two large crickets meet  [  84 5224] [ 0.01582517  0.98417483]
# Round 853 two large crickets meet  [  84 5230] [ 0.0158073  0.9841927]
# Round 854 two large crickets meet  [  84 5236] [ 0.01578947  0.98421053]
# Round 855 two large crickets meet  [  84 5242] [ 0.01577169  0.98422831]
# Round 856 two large crickets meet  [  84 5248] [ 0.01575394  0.98424606]
# Round 857 two large crickets meet  [  84 5254] [ 0.01573623  0.98426377]
# Round 858 two large crickets meet  [  84 5260] [ 0.01571856  0.98428144]
# Round 859 two large crickets meet  [  84 5266] [ 0.01570093  0.98429907]
# Round 860 two large crickets meet  [  84 5272] [ 0.01568335  0.98431665]
# Round 861 two large crickets meet  [  84 5278] [ 0.0156658  0.9843342]
# Round 862 two large crickets meet  [  84 5284] [ 0.01564829  0.98435171]
# Round 863 two large crickets meet  [  84 5290] [ 0.01563082  0.98436918]
# Round 864 two large crickets meet  [  84 5296] [ 0.01561338  0.98438662]
# Round 865 two large crickets meet  [  84 5302] [ 0.01559599  0.98440401]
# Round 866 two large crickets meet  [  84 5308] [ 0.01557864  0.98442136]
# Round 867 two large crickets meet  [  84 5314] [ 0.01556132  0.98443868]
# Round 868 two large crickets meet  [  84 5320] [ 0.01554404  0.98445596]
# Round 869 two large crickets meet  [  84 5326] [ 0.0155268  0.9844732]
# Round 870 two large crickets meet  [  84 5332] [ 0.0155096  0.9844904]
# Round 871 two large crickets meet  [  84 5338] [ 0.01549244  0.98450756]
# Round 872 two large crickets meet  [  84 5344] [ 0.01547531  0.98452469]
# Round 873 two large crickets meet  [  84 5350] [ 0.01545823  0.98454177]
# Round 874 two large crickets meet  [  84 5356] [ 0.01544118  0.98455882]
# Round 875 two large crickets meet  [  84 5362] [ 0.01542416  0.98457584]
# Round 876 two large crickets meet  [  84 5368] [ 0.01540719  0.98459281]
# Round 877 two large crickets meet  [  84 5374] [ 0.01539025  0.98460975]
# Round 878 two large crickets meet  [  84 5380] [ 0.01537335  0.98462665]
# Round 879 two large crickets meet  [  84 5386] [ 0.01535649  0.98464351]
# Round 880 two large crickets meet  [  84 5392] [ 0.01533966  0.98466034]
# Round 881 two large crickets meet  [  84 5398] [ 0.01532287  0.98467713]
# Round 882 two large crickets meet  [  84 5404] [ 0.01530612  0.98469388]
# Round 883 two large crickets meet  [  84 5410] [ 0.01528941  0.98471059]
# Round 884 two large crickets meet  [  84 5416] [ 0.01527273  0.98472727]
# Round 885 two large crickets meet  [  84 5422] [ 0.01525608  0.98474392]
# Round 886 two large crickets meet  [  84 5428] [ 0.01523948  0.98476052]
# Round 887 a small meets a large    [  85 5436] [ 0.01539576  0.98460424]
# Round 888 two large crickets meet  [  85 5442] [ 0.01537905  0.98462095]
# Round 889 two large crickets meet  [  85 5448] [ 0.01536237  0.98463763]
# Round 890 two large crickets meet  [  85 5454] [ 0.01534573  0.98465427]
# Round 891 a small meets a large    [  86 5462] [ 0.01550108  0.98449892]
# Round 892 two large crickets meet  [  86 5468] [ 0.01548434  0.98451566]
# Round 893 two large crickets meet  [  86 5474] [ 0.01546763  0.98453237]
# Round 894 two large crickets meet  [  86 5480] [ 0.01545095  0.98454905]
# Round 895 two large crickets meet  [  86 5486] [ 0.01543431  0.98456569]
# Round 896 two large crickets meet  [  86 5492] [ 0.01541771  0.98458229]
# Round 897 two large crickets meet  [  86 5498] [ 0.01540115  0.98459885]
# Round 898 two large crickets meet  [  86 5504] [ 0.01538462  0.98461538]
# Round 899 two large crickets meet  [  86 5510] [ 0.01536812  0.98463188]
# Round 900 two large crickets meet  [  86 5516] [ 0.01535166  0.98464834]
# Round 901 two large crickets meet  [  86 5522] [ 0.01533524  0.98466476]
# Round 902 two large crickets meet  [  86 5528] [ 0.01531885  0.98468115]
# Round 903 two large crickets meet  [  86 5534] [ 0.01530249  0.98469751]
# Round 904 two large crickets meet  [  86 5540] [ 0.01528617  0.98471383]
# Round 905 two large crickets meet  [  86 5546] [ 0.01526989  0.98473011]
# Round 906 two large crickets meet  [  86 5552] [ 0.01525364  0.98474636]
# Round 907 two large crickets meet  [  86 5558] [ 0.01523742  0.98476258]
# Round 908 two large crickets meet  [  86 5564] [ 0.01522124  0.98477876]
# Round 909 two large crickets meet  [  86 5570] [ 0.01520509  0.98479491]
# Round 910 two large crickets meet  [  86 5576] [ 0.01518898  0.98481102]
# Round 911 two large crickets meet  [  86 5582] [ 0.0151729  0.9848271]
# Round 912 two large crickets meet  [  86 5588] [ 0.01515686  0.98484314]
# Round 913 two large crickets meet  [  86 5594] [ 0.01514085  0.98485915]
# Round 914 two large crickets meet  [  86 5600] [ 0.01512487  0.98487513]
# Round 915 two large crickets meet  [  86 5606] [ 0.01510892  0.98489108]
# Round 916 two large crickets meet  [  86 5612] [ 0.01509302  0.98490698]
# Round 917 two large crickets meet  [  86 5618] [ 0.01507714  0.98492286]
# Round 918 two large crickets meet  [  86 5624] [ 0.0150613  0.9849387]
# Round 919 two large crickets meet  [  86 5630] [ 0.01504549  0.98495451]
# Round 920 two large crickets meet  [  86 5636] [ 0.01502971  0.98497029]
# Round 921 two large crickets meet  [  86 5642] [ 0.01501397  0.98498603]
# Round 922 two large crickets meet  [  86 5648] [ 0.01499826  0.98500174]
# Round 923 two large crickets meet  [  86 5654] [ 0.01498258  0.98501742]
# Round 924 two large crickets meet  [  86 5660] [ 0.01496693  0.98503307]
# Round 925 two large crickets meet  [  86 5666] [ 0.01495132  0.98504868]
# Round 926 two large crickets meet  [  86 5672] [ 0.01493574  0.98506426]
# Round 927 two large crickets meet  [  86 5678] [ 0.01492019  0.98507981]
# Round 928 two large crickets meet  [  86 5684] [ 0.01490468  0.98509532]
# Round 929 two large crickets meet  [  86 5690] [ 0.0148892  0.9851108]
# Round 930 two large crickets meet  [  86 5696] [ 0.01487375  0.98512625]
# Round 931 a small meets a large    [  87 5704] [ 0.01502331  0.98497669]
# Round 932 two large crickets meet  [  87 5710] [ 0.01500776  0.98499224]
# Round 933 two large crickets meet  [  87 5716] [ 0.01499225  0.98500775]
# Round 934 two large crickets meet  [  87 5722] [ 0.01497676  0.98502324]
# Round 935 two large crickets meet  [  87 5728] [ 0.01496131  0.98503869]
# Round 936 two large crickets meet  [  87 5734] [ 0.01494589  0.98505411]
# Round 937 two large crickets meet  [  87 5740] [ 0.0149305  0.9850695]
# Round 938 a small meets a large    [  88 5748] [ 0.01507882  0.98492118]
# Round 939 two large crickets meet  [  88 5754] [ 0.01506333  0.98493667]
# Round 940 two large crickets meet  [  88 5760] [ 0.01504788  0.98495212]
# Round 941 two large crickets meet  [  88 5766] [ 0.01503246  0.98496754]
# Round 942 two large crickets meet  [  88 5772] [ 0.01501706  0.98498294]
# Round 943 two large crickets meet  [  88 5778] [ 0.0150017  0.9849983]
# Round 944 two large crickets meet  [  88 5784] [ 0.01498638  0.98501362]
# Round 945 two large crickets meet  [  88 5790] [ 0.01497108  0.98502892]
# Round 946 two large crickets meet  [  88 5796] [ 0.01495581  0.98504419]
# Round 947 two large crickets meet  [  88 5802] [ 0.01494058  0.98505942]
# Round 948 two large crickets meet  [  88 5808] [ 0.01492537  0.98507463]
# Round 949 two large crickets meet  [  88 5814] [ 0.0149102  0.9850898]
# Round 950 two large crickets meet  [  88 5820] [ 0.01489506  0.98510494]
# Round 951 two large crickets meet  [  88 5826] [ 0.01487995  0.98512005]
# Round 952 two large crickets meet  [  88 5832] [ 0.01486486  0.98513514]
# Round 953 two large crickets meet  [  88 5838] [ 0.01484981  0.98515019]
# Round 954 two large crickets meet  [  88 5844] [ 0.01483479  0.98516521]
# Round 955 two large crickets meet  [  88 5850] [ 0.0148198  0.9851802]
# Round 956 two large crickets meet  [  88 5856] [ 0.01480485  0.98519515]
# Round 957 two large crickets meet  [  88 5862] [ 0.01478992  0.98521008]
# Round 958 two large crickets meet  [  88 5868] [ 0.01477502  0.98522498]
# Round 959 two large crickets meet  [  88 5874] [ 0.01476015  0.98523985]
# Round 960 two large crickets meet  [  88 5880] [ 0.01474531  0.98525469]
# Round 961 two large crickets meet  [  88 5886] [ 0.0147305  0.9852695]
# Round 962 two large crickets meet  [  88 5892] [ 0.01471572  0.98528428]
# Round 963 two large crickets meet  [  88 5898] [ 0.01470097  0.98529903]
# Round 964 two large crickets meet  [  88 5904] [ 0.01468625  0.98531375]
# Round 965 two large crickets meet  [  88 5910] [ 0.01467156  0.98532844]
# Round 966 two large crickets meet  [  88 5916] [ 0.0146569  0.9853431]
# Round 967 two large crickets meet  [  88 5922] [ 0.01464226  0.98535774]
# Round 968 two large crickets meet  [  88 5928] [ 0.01462766  0.98537234]
# Round 969 two large crickets meet  [  88 5934] [ 0.01461309  0.98538691]
# Round 970 two large crickets meet  [  88 5940] [ 0.01459854  0.98540146]
# Round 971 two large crickets meet  [  88 5946] [ 0.01458402  0.98541598]
# Round 972 two large crickets meet  [  88 5952] [ 0.01456954  0.98543046]
# Round 973 two large crickets meet  [  88 5958] [ 0.01455508  0.98544492]
# Round 974 two large crickets meet  [  88 5964] [ 0.01454065  0.98545935]
# Round 975 two large crickets meet  [  88 5970] [ 0.01452625  0.98547375]
# Round 976 a small meets a large    [  89 5978] [ 0.01466952  0.98533048]
# Round 977 two large crickets meet  [  89 5984] [ 0.01465503  0.98534497]
# Round 978 two large crickets meet  [  89 5990] [ 0.01464057  0.98535943]
# Round 979 two large crickets meet  [  89 5996] [ 0.01462613  0.98537387]
# Round 980 two large crickets meet  [  89 6002] [ 0.01461172  0.98538828]
# Round 981 a small meets a large    [  90 6010] [ 0.0147541  0.9852459]
# Round 982 two large crickets meet  [  90 6016] [ 0.0147396  0.9852604]
# Round 983 two large crickets meet  [  90 6022] [ 0.01472513  0.98527487]
# Round 984 two large crickets meet  [  90 6028] [ 0.01471069  0.98528931]
# Round 985 two large crickets meet  [  90 6034] [ 0.01469628  0.98530372]
# Round 986 two large crickets meet  [  90 6040] [ 0.01468189  0.98531811]
# Round 987 two large crickets meet  [  90 6046] [ 0.01466754  0.98533246]
# Round 988 two large crickets meet  [  90 6052] [ 0.01465321  0.98534679]
# Round 989 two large crickets meet  [  90 6058] [ 0.01463891  0.98536109]
# Round 990 two large crickets meet  [  90 6064] [ 0.01462463  0.98537537]
# Round 991 two large crickets meet  [  90 6070] [ 0.01461039  0.98538961]
# Round 992 two large crickets meet  [  90 6076] [ 0.01459617  0.98540383]
# Round 993 a small meets a large    [  91 6084] [ 0.01473684  0.98526316]
# Round 994 two large crickets meet  [  91 6090] [ 0.01472254  0.98527746]
# Round 995 two large crickets meet  [  91 6096] [ 0.01470826  0.98529174]
# Round 996 two large crickets meet  [  91 6102] [ 0.01469401  0.98530599]
# Round 997 two large crickets meet  [  91 6108] [ 0.01467979  0.98532021]
# Round 998 two large crickets meet  [  91 6114] [ 0.01466559  0.98533441]
# Round 999 two large crickets meet  [  91 6120] [ 0.01465142  0.98534858]
# Round 1000 two large crickets meet  [  91 6126] [ 0.01463728  0.98536272]

# %% [markdown]
# The above simulation displays, after each encounter, the number of individuals of each type and the fraction of individuals of each type.   Run the simulation multiple times for different initial conditions.
# <br>**<SPAN style="BACKGROUND-COLOR: #C0C0C0">Problem 2:</SPAN>**  Answer the following questions.   You do not need to provide code for this problem, but explain your answers.
# <ol>
# <li> How quickly does the total population grow if initally all the crickets are small?
# <li> How quickly does the total population grow if initally all the crickets are large?
# <li> Do the fractions converge to a stable equilibrium in which the fractions of both small and large crickets are nonzero? (To explore convergence you may need to increase the number of encounters simulated.)
# </ol>

# %% [markdown]
# __Answer 1:__ If initially all the crickets are small, the total population will grow with rate of 10 since when the small crickets meet another small crickets they will produce 10 offsprings in total. More importantly, all of them are also small crickets.

# %% [markdown]
# __Answer 2:__ If initially all the crickets are large, the total population will grow with rate of $6$ since when the large crickets meet another large crickets they will produce 10 offsprings in total. More importantly, all of them are also large crickets.

# %% [markdown]
# __Answer3:__ Under the condition that both types of crickets start with the same amount. As number of iteration increases, the fraction of large crickets over total number of crickets is approaching $1$ and the fraction of small crickets over total number of crickets is approaching $0$.

# %% [markdown]
# **<SPAN style="BACKGROUND-COLOR: #C0C0C0">End of Problem 2</SPAN>**

# %% [markdown]
# The code given next is essentially the same as above.  One difference is a time variable is added such that the average rate that an individual cricket has encounters is proportional to the total number of crickets.  This results in exponential growth of the population with time.    Another difference is that population sizes are saved and plotted.

# %%
# Stochastic simulation of replicator dynamics for cricket game
# Time is scaled so contact rate of each individual is one per unit time
# The evolution trajectory is stored an plotted

F=np.array([[5,1],[8,3]])  # fitness matrix
n_max=100  # maximum number of interactions
n=np.zeros((n_max,2),dtype=float)
time=np.zeros(n_max,dtype=float)

n[0,0], n[0,1] = 4,4 # initial [number of small crickets, number of large crickets]

for k in range(n_max-1):
    time[k+1]=time[k]+2.0/sum(n[k,:])   # The 2 is here because two individuals make contact at a time
    a=n[k,0]*(n[k,0]-1.0)/((n[k,0]+n[k,1])*(n[k,0]+n[k,1]-1))  # probability both players are type 0
    b=2*n[k,0]*n[k,1]/((n[k,0]+n[k,1])*(n[k,0]+n[k,1]-1.0))  # probability one player of each type
    U=np.random.rand()
    if U<=a:
        n[k+1,:]= n[k,:] + [2*F[0,0],0]
    elif a<U<=a+b:
        n[k+1,:]=n[k,:] + [F[0,1],F[1,0]]
    else:
        n[k+1,:]= n[k,:] + [0,2*F[1,1]]

plt.plot(time,n[:,0],'orange')
plt.plot(time,n[:,1],'blue')
plt.text(1.1,n[80,0], r'small',fontsize=14)
plt.text(1.1,n[80,1], r'large',fontsize=14)
plt.xlabel('time')
plt.ylabel('population size')
plt.title("Numbers of small and large crickets vs. time (simulation)")

# %% [markdown]
# The following code computes the deterministic analog of the cricket evolution.  The basic idea is that if the current population is [n[0], n[1]] then the drift (i.e. the expected rate of increase) of n[0] is n[0]  multiplied by the expected number of small crickets generated by a small cricket if an encounter happens.  That is true because each of the existing small crikets is having encounters at expected rate one.   To calculate the mean number of new small crickets generated by the encounter of a small cricket with a randomly selected other cricket, we use the law of total probability.  The encountered cricket is type zero with probabiity n[0]/(n[0]+n[1]), which results in F[0,0] new crickets of type zero, and the encountered cricket is type one with probability n[1]/(n[0]+n[1]), which results in F[0,1] new crickets of type zero.   Combining we get
# $$
# \dot{n}[0] = n[0]*(F[0,0]*n[0]+F[0,1]*n[1])/(n[0]+n[1])
# $$
# The equation just derived is based on the law of large numbers (LLN).  If the population is fairly large then no one individual plays a major role in the evolution.  Over a small period of time the ratios of small and large crickets is nearly constant, so the number of new crickets of each type in each time slot are nearly independent and identically distributed.   The LLN suggests approximating the sum of number of individuals of each type by the expected numbers of individuals of each type.  That's how we arrive at a deterministic differential equation.
#
# A similar expression holds for the derivative of n[1], and the two equations can be writen in matrix form as
# $$
# \dot{n} = diag(n)*F*n/sum(n)
# $$
# where diag(n) is the diagonal matrix with n[0] and n[1] on the diagonal, and "$*$" represents usual matrix multiplication.   (In the python code below, "$*$" denotes element by element multiplication, which is used instead of creating a diagonal matrix, and np.dot is used for ordinary matrix multiplication.)

# %%
# Deterministic (ODE) replicator dynamics for cricket game
from scipy.integrate import odeint

F=np.array([[5,1],[8,3]])  # fitness matrix

def f(n,t):
    return (n*np.dot(F,n)/sum(n)/1.)

ninit=[10, 1]    # initial [number of small crickets, number of large crickets]
time=np.linspace(0.0,1.5, 1000)

n=odeint(f,ninit,time)

plt.plot(time,n[:,0],'orange')
plt.plot(time,n[:,1],'blue')
plt.xlabel('time')
plt.text(1.1,n[800,0], r'small',fontsize=14)
plt.text(1.1,n[800,1], r'large',fontsize=14)
plt.ylabel('population size')
plt.title("Numbers of small and large crickets vs. time (ode prediction)")

# %% [markdown]
# <br>**<SPAN style="BACKGROUND-COLOR: #C0C0C0">Problem 3:</SPAN>** Run the code above and compare the output to the output of the previous code for stochastic evolutionary dynamics.  Try different intial conditions such as [0,4], [4,0], and [10,1]. Comment on how the result of this compares to our previous simulation. Is the behavior similar?

# %% [markdown]
# __Answer__: When the initial condition is $[0,4]$, the graph consists only the plot of the number of large crickets. When the initial condiditoi is $[4,0]$, the graph consists only the plot of the number of small crickets. When the initial condition is $[10,1]$, the graph looks mostly similar to the curve for $[4,4]$ with only the slope of the curve for small crickets is bigger.

# %% [markdown]
# **<SPAN style="BACKGROUND-COLOR: #C0C0C0">End of Problem 3</SPAN>**

# %% [markdown]
# If we let $\theta[0]=\frac{n[0]}{n[0]+n[1]}$ and $\theta[1]=\frac{n[1]}{n[0]+n[1]}$ then the vector $\theta=\binom{\theta[0]}{\theta[1]}$ describes the fractions of the popuation of each type.  It's entries sum to one.  Using the chain rule of calculus we can derive the following differential equation for $\theta$ from the above ode for $n$:
# $$
# \dot{\theta} = diag(\theta) \left( F\theta - \mathbf{1} \theta^T F \theta \right)
# $$
# where $\mathbf{1}$ is the column vector of ones (the derivation is a bit involved, try deriving it by yourself if interested, but it is not required). The two components of the vector $F \theta$ give the average fitness level of small crickets and large crickets, respectively, in an encounter with a cricket selected randomly from the population.   And $\theta^T F \theta$ is the weighted average of that vector, giving the average fitness over all crickets in the population.   Thus, $\theta[0]$ is increasing exactly when the fitness of small crickets is greater than the average fitness.
#
# <br>**<SPAN style="BACKGROUND-COLOR: #C0C0C0">Problem 4:</SPAN>**
#
# 1. Modify the above code to integrate the equation for the $\theta$ vector to obtain $\theta$ vs. time.
# To check your answer, compare it to what you get by first computing the trajectory of $n$ and then calculating $\theta$ from $n.$  (The code given above for deterministic evolution of n works for any number of types, not just two types. A problem below involves three types of individuals, so it'd be nice if you could implement your code for computing $\theta$ to work for any number of types.) __Be careful when you write your program, since matrix multiplication in Python can be tricky. Understand "$*$" multiplication and np.dot multiplication first. After each small step, debug, confirm, then proceed.__
# 2. Using the fact that $\theta[1]=1-\theta[0],$  a differential equation can be derived for the variable $\theta[0]$ alone.
# Plot the function $h$ on the interval $[0,1]$ such that $\dot{\theta}[0]=h(\theta[0]).$ Note that the horizontal axis of the graph is $\theta$, the vertical axis is $\dot{\theta}$. (You can just do this
# numerically.  It can also be done algebrically; in fact $h$ is a cubic polynomial, but it is a bit complicated to find the polynomial.)
# 3. What are the zeroes of $h$ (those are the equilibrium points of $\theta[0]$)?  Which of those are stable (in the sense that if $\theta[0]$ is slightly moved away from the equilibrium point, it returns to the equilibrium point)?

# %%
####### Part 1 #######
F=np.array([[5,1],[8,3]])  # fitness matrix

def f_integrate(theta,t):
    avg_fit = np.dot(F, theta)
    theta_matx = np.tile(theta, (2,1))
    return theta*(avg_fit - np.dot(theta_matx, avg_fit))

theta_init = [0.5, 0.5]
time=np.linspace(0.0,1.5, 1000)

integrated = odeint(f_integrate, theta_init, time)

plt.plot(time,integrated[:,0],'orange')
plt.plot(time,integrated[:,1],'blue')
plt.xlabel('time')
plt.text(1.1,n[800,0], r'small',fontsize=14)
plt.text(1.1,n[800,1], r'large',fontsize=14)
plt.ylabel('Integrated $\\theta$')
plt.title("Integrated $\\theta$ vector vs. time")

# %%
time = np.linspace(0.0, 1.0, 1000)

def h(theta):     # Same as what we had before but with the input parameter changed
    avg_fit = np.dot(F, theta)
    theta_matx = np.tile(theta, (2,1))
    return theta*(avg_fit - np.dot(theta_matx, avg_fit))


theta = [h([x, 1-x])[0] for x in time]
plt.plot(time, theta)

# %% [markdown]
# __Answer:__ There are two $0$, one is at $\theta = 0$ and another one is $\theta = 1$. When $\theta = 0$, there should be a stable equilibrium point. Combining the above two graphs, we are able to tell that when $\theta$ is in between $0$ and $1$, the fraction of small cricket will gradually converge to 0 eventually, which is confirmed by the graph of integrated $\theta$ graph overtime.

# %% [markdown]
# **<SPAN style="BACKGROUND-COLOR: #C0C0C0">End of Problem 4</SPAN>**

# %% [markdown]
# The overall behavior in evolutionary games depends heavily on the fitness matrix $F.$   Another choice of $F$ corresponds to the so-called doves and hawks evolution game, for which the fitness matrix is
# $$\begin{array}{c|cc}  & dove & hawk  \\ \hline
#     dove & 3 & 1  \\
#     hawk & 5 & 0
#     \end{array}$$
# or by a fitness matrix
# $$F=\left( \begin{array}{cc}  3 & 1 \\ 5 & 0  \end{array}\right).$$   Think of the doves and hawks as two types of birds that need to share resources, such as food.  (The hawks are so aggressive that they attack the doves).  A dove has higher fitness, 3, against another dove than against a hawk, 1.  A hawk has a high fitness against a dove (5) but zero fitness against another hawk, because the hawks fight over their resources.
#
# <br>**<SPAN style="BACKGROUND-COLOR: #C0C0C0">Problem 5:</SPAN>**
#
# 1. Repeat the deterministic (ode) approach above, but now for the doves and hawks evolution game.   You can use either the random or deterministic evolution equations for the numerical analysis.
# 2. Comment and verify your assertions about equilibrium behavior by finding a differential equation for $\theta[0]$ and exploring its equilbrium points and their stability.

# %%
F = np.array([[3,1],[5,0]])

def f(n,t):
    return (n*np.dot(F,n)/sum(n)/1.)

ninit=[4, 4]    # initial [number of small crickets, number of large crickets]
time=np.linspace(0.0,1.5, 1000)

n=odeint(f,ninit,time)

plt.plot(time,n[:,0],'orange')
plt.plot(time,n[:,1],'blue')
plt.xlabel('time')
plt.text(1.1,n[800,0], r'dove',fontsize=14)
plt.text(1.1,n[800,1], r'hawk',fontsize=14)
plt.ylabel('population size')
plt.title("Numbers of doves and hawks. time (ode prediction)")

# %%
F = np.array([[3,1],[5,0]])  # fitness matrix

theta_init = [0.5, 0.5]
time=np.linspace(0.0,1.5, 1000)

integrated = odeint(f_integrate, theta_init, time)

plt.plot(time,integrated[:,0],'orange', label='dove')
plt.plot(time,integrated[:,1],'blue', label='hawk')
plt.xlabel('time')
plt.legend()
plt.ylabel('Integrated $\\theta$')
plt.title("Integrated $\\theta$ vector vs. time")

# %%
time = np.linspace(0.0, 1.0, 1000)

def h(theta):     # Same as what we had before but with the input parameter changed
    avg_fit = np.dot(F, theta)
    theta_matx = np.tile(theta, (2,1))
    return theta*(avg_fit - np.dot(theta_matx, avg_fit))


theta = [h([x, 1-x])[0] for x in time]
plt.figure(2)
plt.plot(time, theta)
plt.title('Plot of h on the interval [0,1] such that $\\theta[0]=h(\\theta[0])$')

# %% [markdown]
# __Answer__:From the integration graph, we are able to tell that neither the dove nor the hawk will converge to 0. When there is only doves, the number of dove will converge to a number instead of keeping growing. Same for hawks, if it starts off with only hawks, they will not keep growing without limit.

# %% [markdown]
# From the graph we can tell the fraction of dove eventually is converging to $\frac{1}{3}$. Combining with the observation on the second graph, we can say that there are $3$ eq points: $0$, $1$, and $\frac{1}{3}$. $1$ and $0$ can only be attained and preserved if the system only has one specie. Therefore only $\frac{1}{3}$ is stable.

# %% [markdown]
# **<SPAN style="BACKGROUND-COLOR: #C0C0C0">End of Problem 5</SPAN>**

# %% [markdown]
# **<SPAN style="BACKGROUND-COLOR: #C0C0C0">Problem 6:</SPAN>**  Find a 3x3 fitness matrix $F$ and an initial condition for an evolutionary game with three types of individuals such that the solution $\theta$ has a limit cycle, not just converging to a limit point.  Does the limit cycle depend on the intial state for your fitness matrix?
#
# Hint 1: Adapt the code you wrote for Problem 4.
#
# Hint 2: Solve this problem by trial and error, i.e. trying different values of the entries in the fitness matrix. Think of the three types of individuals as three kinds of animals. What kind of relationship among these three animals would likely to cause an oscillating population for each animal?

# %%
F = np.array([[0,-4,4], [4,0,-4], [-4, 4, 0]])

def f_integrate(theta,t):
    avg_fit = np.dot(F, theta)
    theta_matx = np.tile(theta, (3,1))
    return theta*(avg_fit - np.dot(theta_matx, avg_fit))

theta_init = [0.3, 0.4, 0.3]
time=np.linspace(0.0,2.5, 1000)

integrated = odeint(f_integrate, theta_init, time)

plt.plot(time,integrated[:,0],'orange', label='a')
plt.plot(time,integrated[:,1],'blue', label='b')
plt.plot(time,integrated[:,2],'red', label='c')
plt.xlabel('time')
plt.ylabel('Integrated $\\theta$')
plt.title("Integrated $\\theta$ vector vs. time")
plt.legend()

# %% [markdown]
# __Answer__: The limit cycle doesn't depend on the intial state for the fitness matrix. As long as there is no specie starts with $0$ fraction, each specie will have a dynamic oscillating equilibrium: one goes up, the others go down and repeat.

# %% [markdown]
# **<SPAN style="BACKGROUND-COLOR: #C0C0C0">End of Problem 6</SPAN>**

# %% [markdown]
# For this week's lab, please answer all questions 1-6.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# ## Academic Integrity Statement ##
#
# By submitting the lab with this statement, you declare you have written up the lab entirely by yourself, including both code and markdown cells. You also agree that you should not share your code with anyone else. Any violation of the academic integrity requirement may cause an academic integrity report to be filed that could go into your student record. See <a href="https://provost.illinois.edu/policies/policies/academic-integrity/students-quick-reference-guide-to-academic-integrity/">Students' Quick Reference Guide to Academic Integrity</a> for more information.
